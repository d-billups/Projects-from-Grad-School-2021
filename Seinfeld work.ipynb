# %%
import pandas as pd
import csv

# %%
#df = pd.read_csv('/Users/diorbillups/Downloads/module-A-2/data/scripts.csv')

# %%
path = '/Users/diorbillups/Downloads/useful_datasets/scripts.csv'

c = open(path, 'r', encoding='UTF-8')

script = list(c)

# %%
c_read = csv.reader(open(path,'r'))
c_list = list(c_read)

# %%
#(4 pts) Now collect the data from the Character column and 
#load it into a list called speakers to complete the below function.

header = c_list[0] 
full = c_list[1:] #exclude the headers

speakers = []

for i in full:
    speakers.append(i[1])

# %%
speakers
# Out:
# ['JERRY',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'CLAIRE',
#  'GEORGE',
#  'CLAIRE',
#  'JERRY',
#  'CLAIRE',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'CLAIRE',
#  'GEORGE',
#  'GEORGE',
#  'CLAIE',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'CLAIRE',
#  '(George shows his note-block to Jerry; it says very largely',
#  'CLAIRE',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'CLAIRE',
#  'GEORGE',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
#  'GEORGE',
#  'JERRY',
# ...

# %%
#df[(df['Season']==1) & df['EpisodeNo']==1.0]

# %%
# Now count the dialogue entries for the 
  #  four major characters ("JERRY", "GEORGE", "ELAINE", and "KRAMER"), 
 #   using your output from the get_speakers() 
  #  function and a dictionary (you are not allowed to use the 
   # Counter data structure for any component of this module).

# %%
cast= {'ELAINE': 0,
      'JERRY': 0,
      'GEORGE': 0,
      'KRAMER': 0}

for person in speakers:
    if person == 'JERRY':
        cast['JERRY']+=1
    if person == 'ELAINE':
        cast['ELAINE']+=1
    if person == 'GEORGE':
        cast['GEORGE']+=1
    if person == 'KRAMER':
        cast['KRAMER']+=1

# %%
cast
# Out:
# {'ELAINE': 7983, 'JERRY': 14786, 'GEORGE': 9708, 'KRAMER': 6664}

# %%
words =full[2][2]

# %%
w = words.split()

d = {'MARK': 0}

for x in w:
    d['MARK']+=1

# %%
spoken = {'JERRY': 0,
         'GEORGE': 0,
         'ELAINE': 0,
         'KRAMER': 0}

full = c_list[1:]
for i in full:
    person = i[1]
    dialogue = i[2]
    if person == 'JERRY':
        words = dialogue.split()
        for w in words:
            spoken['JERRY']+=1
    if person == 'ELAINE':
        words = dialogue.split()
        for w in words:
            spoken['ELAINE']+=1
    if person == 'GEORGE':
        words = dialogue.split()
        for w in words:
            spoken['GEORGE']+=1
    if person == 'KRAMER':
        words = dialogue.split()
        for w in words:
            spoken['KRAMER']+=1

# %%
spoken
# Out:
# {'JERRY': 147389, 'GEORGE': 107029, 'ELAINE': 74634, 'KRAMER': 70299}
