# %% [markdown]
# (5 points) You will be using part of the Goodbooks 10k dataset for this module. To start, complete the function and read the data/goodreads-books.csv file into a list. Your output should be a list of dictionaries (one for for each book), which each contain the following fields: 'authors', original 'title', original 'publication year', 'average rating', and 'ratings count'. Note: you must convert the average rating and ratings count into float and int types, respectively.

# %%
import csv
import pandas as pd
import regex as re

# %%
books = csv.reader(open('/Users/diorbillups/DSCI_511_Assignments/Good_books_assignment/data/goodreads-books.csv','r'))
book = list(books)

# %%
header = book[0]

# %%
header
# Out:
# ['book_id',
#  'goodreads_book_id',
#  'best_book_id',
#  'work_id',
#  'books_count',
#  'isbn',
#  'isbn13',
#  'authors',
#  'original_publication_year',
#  'original_title',
#  'title',
#  'language_code',
#  'average_rating',
#  'ratings_count',
#  'work_ratings_count',
#  'work_text_reviews_count',
#  'ratings_1',
#  'ratings_2',
#  'ratings_3',
#  'ratings_4',
#  'ratings_5',
#  'image_url',
#  'small_image_url']

# %%
#Grabbing the indices for all of the categories we

# %%
auth = header.index('authors')
orig_title = header.index('original_title')
orig_pubyear = header.index('original_publication_year')
avg_r = header.index('average_rating')
rating_count = header.index('ratings_count')

# %%
l = []

for i in book[1:]:
    info = {}
    rating_c = int(float(i[rating_count]))
    avg = float(i[avg_r])
    py = i[orig_pubyear]
    j = ''.join(re.findall('\d{4}',py))
    
    info['author']=i[auth]
    info['original_title']=i[orig_title]
    info['original_pub_year']=j
    info['avg_rating']=avg
    info['ratings_count']=rating_c
    
    l.append(info)

# %%
l
# Out:
# [{'author': 'Suzanne Collins',
#   'original_title': 'The Hunger Games',
#   'original_pub_year': '2008',
#   'avg_rating': 4.34,
#   'ratings_count': 4780653},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': "Harry Potter and the Philosopher's Stone",
#   'original_pub_year': '1997',
#   'avg_rating': 4.44,
#   'ratings_count': 4602479},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Twilight',
#   'original_pub_year': '2005',
#   'avg_rating': 3.57,
#   'ratings_count': 3866839},
#  {'author': 'Harper Lee',
#   'original_title': 'To Kill a Mockingbird',
#   'original_pub_year': '1960',
#   'avg_rating': 4.25,
#   'ratings_count': 3198671},
#  {'author': 'F. Scott Fitzgerald',
#   'original_title': 'The Great Gatsby',
#   'original_pub_year': '1925',
#   'avg_rating': 3.89,
#   'ratings_count': 2683664},
#  {'author': 'John Green',
#   'original_title': 'The Fault in Our Stars',
#   'original_pub_year': '2012',
#   'avg_rating': 4.26,
#   'ratings_count': 2346404},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Hobbit or There and Back Again',
#   'original_pub_year': '1937',
#   'avg_rating': 4.25,
#   'ratings_count': 2071616},
#  {'author': 'J.D. Salinger',
#   'original_title': 'The Catcher in the Rye',
#   'original_pub_year': '1951',
#   'avg_rating': 3.79,
#   'ratings_count': 2044241},
#  {'author': 'Dan Brown',
#   'original_title': 'Angels & Demons ',
#   'original_pub_year': '2000',
#   'avg_rating': 3.85,
#   'ratings_count': 2001311},
#  {'author': 'Jane Austen',
#   'original_title': 'Pride and Prejudice',
#   'original_pub_year': '1813',
#   'avg_rating': 4.24,
#   'ratings_count': 2035490},
#  {'author': 'Khaled Hosseini',
#   'original_title': 'The Kite Runner ',
#   'original_pub_year': '2003',
#   'avg_rating': 4.26,
#   'ratings_count': 1813044},
#  {'author': 'Veronica Roth',
#   'original_title': 'Divergent',
#   'original_pub_year': '2011',
#   'avg_rating': 4.24,
#   'ratings_count': 1903563},
#  {'author': 'George Orwell, Erich Fromm, Celâl Üster',
#   'original_title': 'Nineteen Eighty-Four',
#   'original_pub_year': '1949',
#   'avg_rating': 4.14,
#   'ratings_count': 1956832},
#  {'author': 'George Orwell',
#   'original_title': 'Animal Farm: A Fairy Story',
#   'original_pub_year': '1945',
#   'avg_rating': 3.87,
#   'ratings_count': 1881700},
#  {'author': 'Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-Doubleday',
#   'original_title': 'Het Achterhuis: Dagboekbrieven 14 juni 1942 - 1 augustus 1944',
#   'original_pub_year': '1947',
#   'avg_rating': 4.1,
#   'ratings_count': 1972666},
#  {'author': 'Stieg Larsson, Reg Keeland',
#   'original_title': 'Män som hatar kvinnor',
#   'original_pub_year': '2005',
#   'avg_rating': 4.11,
#   'ratings_count': 1808403},
#  {'author': 'Suzanne Collins',
#   'original_title': 'Catching Fire',
#   'original_pub_year': '2009',
#   'avg_rating': 4.3,
#   'ratings_count': 1831039},
#  {'author': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'original_title': 'Harry Potter and the Prisoner of Azkaban',
#   'original_pub_year': '1999',
#   'avg_rating': 4.53,
#   'ratings_count': 1832823},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': ' The Fellowship of the Ring',
#   'original_pub_year': '1954',
#   'avg_rating': 4.34,
#   'ratings_count': 1766803},
#  {'author': 'Suzanne Collins',
#   'original_title': 'Mockingjay',
#   'original_pub_year': '2010',
#   'avg_rating': 4.03,
#   'ratings_count': 1719760},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Order of the Phoenix',
#   'original_pub_year': '2003',
#   'avg_rating': 4.46,
#   'ratings_count': 1735368},
#  {'author': 'Alice Sebold',
#   'original_title': 'The Lovely Bones',
#   'original_pub_year': '2002',
#   'avg_rating': 3.77,
#   'ratings_count': 1605173},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Chamber of Secrets',
#   'original_pub_year': '1998',
#   'avg_rating': 4.37,
#   'ratings_count': 1779331},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Goblet of Fire',
#   'original_pub_year': '2000',
#   'avg_rating': 4.53,
#   'ratings_count': 1753043},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Deathly Hallows',
#   'original_pub_year': '2007',
#   'avg_rating': 4.61,
#   'ratings_count': 1746574},
#  {'author': 'Dan Brown',
#   'original_title': 'The Da Vinci Code',
#   'original_pub_year': '2003',
#   'avg_rating': 3.79,
#   'ratings_count': 1447148},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Half-Blood Prince',
#   'original_pub_year': '2005',
#   'avg_rating': 4.54,
#   'ratings_count': 1678823},
#  {'author': 'William Golding',
#   'original_title': 'Lord of the Flies ',
#   'original_pub_year': '1954',
#   'avg_rating': 3.64,
#   'ratings_count': 1605019},
#  {'author': 'William Shakespeare, Robert           Jackson',
#   'original_title': 'An Excellent conceited Tragedie of Romeo and Juliet',
#   'original_pub_year': '1595',
#   'avg_rating': 3.73,
#   'ratings_count': 1628519},
#  {'author': 'Gillian Flynn',
#   'original_title': 'Gone Girl',
#   'original_pub_year': '2012',
#   'avg_rating': 4.03,
#   'ratings_count': 512475},
#  {'author': 'Kathryn Stockett',
#   'original_title': 'The Help',
#   'original_pub_year': '2009',
#   'avg_rating': 4.45,
#   'ratings_count': 1531753},
#  {'author': 'John Steinbeck',
#   'original_title': 'Of Mice and Men ',
#   'original_pub_year': '1937',
#   'avg_rating': 3.84,
#   'ratings_count': 1467496},
#  {'author': 'Arthur Golden',
#   'original_title': 'Memoirs of a Geisha',
#   'original_pub_year': '1997',
#   'avg_rating': 4.08,
#   'ratings_count': 1300209},
#  {'author': 'E.L. James',
#   'original_title': 'Fifty Shades of Grey',
#   'original_pub_year': '2011',
#   'avg_rating': 3.67,
#   'ratings_count': 1338493},
#  {'author': 'Paulo Coelho, Alan R. Clarke',
#   'original_title': 'O Alquimista',
#   'original_pub_year': '1988',
#   'avg_rating': 3.82,
#   'ratings_count': 1299566},
#  {'author': 'Lois Lowry',
#   'original_title': 'The Giver',
#   'original_pub_year': '1993',
#   'avg_rating': 4.12,
#   'ratings_count': 1296825},
#  {'author': 'C.S. Lewis',
#   'original_title': 'The Lion, the Witch and the Wardrobe',
#   'original_pub_year': '1950',
#   'avg_rating': 4.19,
#   'ratings_count': 1531800},
#  {'author': 'Audrey Niffenegger',
#   'original_title': "The Time Traveler's Wife",
#   'original_pub_year': '2003',
#   'avg_rating': 3.95,
#   'ratings_count': 746287},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Game of Thrones',
#   'original_pub_year': '1996',
#   'avg_rating': 4.45,
#   'ratings_count': 1319204},
#  {'author': 'Elizabeth Gilbert',
#   'original_title': "Eat, pray, love: one woman's search for everything across Italy, India and Indonesia",
#   'original_pub_year': '2006',
#   'avg_rating': 3.51,
#   'ratings_count': 1181647},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Lightning Thief',
#   'original_pub_year': '2005',
#   'avg_rating': 4.23,
#   'ratings_count': 1366265},
#  {'author': 'Louisa May Alcott',
#   'original_title': 'Little Women',
#   'original_pub_year': '1868',
#   'avg_rating': 4.04,
#   'ratings_count': 1257121},
#  {'author': 'Charlotte Brontë, Michael Mason',
#   'original_title': 'Jane Eyre',
#   'original_pub_year': '1847',
#   'avg_rating': 4.1,
#   'ratings_count': 1198557},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'The Notebook',
#   'original_pub_year': '1996',
#   'avg_rating': 4.06,
#   'ratings_count': 1053403},
#  {'author': 'Yann Martel',
#   'original_title': 'Life of Pi',
#   'original_pub_year': '2001',
#   'avg_rating': 3.88,
#   'ratings_count': 1003228},
#  {'author': 'Sara Gruen',
#   'original_title': 'Water for Elephants',
#   'original_pub_year': '2006',
#   'avg_rating': 4.07,
#   'ratings_count': 1068146},
#  {'author': 'Markus Zusak',
#   'original_title': 'The Book Thief',
#   'original_pub_year': '2005',
#   'avg_rating': 4.36,
#   'ratings_count': 1159741},
#  {'author': 'Ray Bradbury',
#   'original_title': 'Fahrenheit 451',
#   'original_pub_year': '1953',
#   'avg_rating': 3.97,
#   'ratings_count': 570498},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'New Moon (Twilight, #2)',
#   'original_pub_year': '2006',
#   'avg_rating': 3.52,
#   'ratings_count': 1149630},
#  {'author': 'Shel Silverstein',
#   'original_title': 'Where the Sidewalk Ends: The Poems and Drawings of Shel Silverstein',
#   'original_pub_year': '1974',
#   'avg_rating': 4.29,
#   'ratings_count': 1016888},
#  {'author': 'Cassandra Clare',
#   'original_title': 'City of Bones',
#   'original_pub_year': '2007',
#   'avg_rating': 4.12,
#   'ratings_count': 1154031},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Eclipse',
#   'original_pub_year': '2007',
#   'avg_rating': 3.69,
#   'ratings_count': 1134511},
#  {'author': 'Christopher Paolini',
#   'original_title': 'Eragon',
#   'original_pub_year': '2002',
#   'avg_rating': 3.86,
#   'ratings_count': 1104021},
#  {'author': 'Douglas Adams',
#   'original_title': "The Hitchhiker's Guide to the Galaxy",
#   'original_pub_year': '1979',
#   'avg_rating': 4.2,
#   'ratings_count': 936782},
#  {'author': 'Aldous Huxley',
#   'original_title': 'Brave New World',
#   'original_pub_year': '1932',
#   'avg_rating': 3.97,
#   'ratings_count': 1022601},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Breaking Dawn',
#   'original_pub_year': '2008',
#   'avg_rating': 3.7,
#   'ratings_count': 1070245},
#  {'author': 'Sue Monk Kidd',
#   'original_title': 'The Secret Life of Bees',
#   'original_pub_year': '2001',
#   'avg_rating': 4.01,
#   'ratings_count': 916189},
#  {'author': 'Mark Twain, John Seelye, Guy Cardwell',
#   'original_title': 'The Adventures of Huckleberry Finn',
#   'original_pub_year': '1884',
#   'avg_rating': 3.8,
#   'ratings_count': 953758},
#  {'author': 'E.B. White, Garth Williams, Rosemary Wells',
#   'original_title': "Charlotte's Web",
#   'original_pub_year': '1952',
#   'avg_rating': 4.15,
#   'ratings_count': 1064521},
#  {'author': 'Mark Haddon',
#   'original_title': 'The Curious Incident of the Dog in the Night-Time',
#   'original_pub_year': '2003',
#   'avg_rating': 3.85,
#   'ratings_count': 867553},
#  {'author': 'Paula Hawkins',
#   'original_title': 'The Girl on the Train',
#   'original_pub_year': '2015',
#   'avg_rating': 3.88,
#   'ratings_count': 1008778},
#  {'author': 'Philip Pullman',
#   'original_title': 'Northern Lights',
#   'original_pub_year': '1995',
#   'avg_rating': 3.94,
#   'ratings_count': 953970},
#  {'author': 'Emily Brontë, Richard J. Dunn',
#   'original_title': 'Wuthering Heights',
#   'original_pub_year': '1847',
#   'avg_rating': 3.82,
#   'ratings_count': 899195},
#  {'author': 'Jodi Picoult',
#   'original_title': "My Sister's Keeper",
#   'original_pub_year': '2004',
#   'avg_rating': 4.06,
#   'ratings_count': 863879},
#  {'author': 'Kurt Vonnegut Jr.',
#   'original_title': "Slaughterhouse-Five, or The Children's Crusade: A Duty-Dance with Death ",
#   'original_pub_year': '1969',
#   'avg_rating': 4.06,
#   'ratings_count': 846488},
#  {'author': 'Margaret Mitchell',
#   'original_title': 'Gone with the Wind',
#   'original_pub_year': '1936',
#   'avg_rating': 4.28,
#   'ratings_count': 873981},
#  {'author': 'Khaled Hosseini',
#   'original_title': 'A Thousand Splendid Suns',
#   'original_pub_year': '2007',
#   'avg_rating': 4.34,
#   'ratings_count': 818742},
#  {'author': 'Stephen Chbosky',
#   'original_title': 'The Perks of Being a Wallflower',
#   'original_pub_year': '1999',
#   'avg_rating': 4.21,
#   'ratings_count': 888806},
#  {'author': 'Veronica Roth',
#   'original_title': 'Insurgent',
#   'original_pub_year': '2012',
#   'avg_rating': 4.07,
#   'ratings_count': 836362},
#  {'author': 'Orson Scott Card',
#   'original_title': "Ender's Game",
#   'original_pub_year': '1985',
#   'avg_rating': 4.3,
#   'ratings_count': 813439},
#  {'author': 'Mary Wollstonecraft Shelley, Percy Bysshe Shelley, Maurice Hindle',
#   'original_title': 'Frankenstein; or, The Modern Prometheus',
#   'original_pub_year': '1818',
#   'avg_rating': 3.75,
#   'ratings_count': 808589},
#  {'author': 'Stephen King',
#   'original_title': 'The Shining',
#   'original_pub_year': '1977',
#   'avg_rating': 4.17,
#   'ratings_count': 791850},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'The Host',
#   'original_pub_year': '2008',
#   'avg_rating': 3.84,
#   'ratings_count': 749780},
#  {'author': 'John Green',
#   'original_title': 'Looking for Alaska',
#   'original_pub_year': '2005',
#   'avg_rating': 4.09,
#   'ratings_count': 783470},
#  {'author': 'Helen Fielding',
#   'original_title': '',
#   'original_pub_year': '1996',
#   'avg_rating': 3.75,
#   'ratings_count': 736498},
#  {'author': 'Jane Austen, Tony Tanner, Ros Ballaster',
#   'original_title': 'Sense and Sensibility',
#   'original_pub_year': '1811',
#   'avg_rating': 4.06,
#   'ratings_count': 738894},
#  {'author': 'Louis Sachar, Louis Sachar',
#   'original_title': 'Holes',
#   'original_pub_year': '1998',
#   'avg_rating': 3.93,
#   'ratings_count': 747445},
#  {'author': 'Lauren Weisberger',
#   'original_title': 'The Devil Wears Prada',
#   'original_pub_year': '2003',
#   'avg_rating': 3.7,
#   'ratings_count': 665930},
#  {'author': 'Homer, Robert Fagles, E.V. Rieu, Frédéric Mugler, Bernard Knox',
#   'original_title': 'Ὀδύσσεια',
#   'original_pub_year': '',
#   'avg_rating': 3.73,
#   'ratings_count': 670326},
#  {'author': 'Antoine de Saint-Exupéry, Richard Howard, Dom Marcos Barbosa, Melina Karakosta',
#   'original_title': 'Le Petit Prince',
#   'original_pub_year': '1946',
#   'avg_rating': 4.28,
#   'ratings_count': 738757},
#  {'author': 'Jeannette Walls',
#   'original_title': 'The Glass Castle',
#   'original_pub_year': '2005',
#   'avg_rating': 4.24,
#   'ratings_count': 621099},
#  {'author': 'Jon Krakauer',
#   'original_title': 'Into the Wild',
#   'original_pub_year': '1996',
#   'avg_rating': 3.94,
#   'ratings_count': 647684},
#  {'author': 'Charles Dickens, Richard Maxwell, Hablot Knight Browne',
#   'original_title': 'A Tale of Two Cities',
#   'original_pub_year': '1859',
#   'avg_rating': 3.81,
#   'ratings_count': 637412},
#  {'author': 'Michael Crichton',
#   'original_title': 'Jurassic Park',
#   'original_pub_year': '1990',
#   'avg_rating': 3.96,
#   'ratings_count': 447833},
#  {'author': 'Shel Silverstein',
#   'original_title': 'The Giving Tree',
#   'original_pub_year': '1964',
#   'avg_rating': 4.38,
#   'ratings_count': 702332},
#  {'author': 'John Grisham',
#   'original_title': 'A Time to Kill',
#   'original_pub_year': '1989',
#   'avg_rating': 4.03,
#   'ratings_count': 597775},
#  {'author': 'Elie Wiesel, Marion Wiesel',
#   'original_title': 'Un di Velt Hot Geshvign',
#   'original_pub_year': '1958',
#   'avg_rating': 4.3,
#   'ratings_count': 691231},
#  {'author': 'John Green',
#   'original_title': 'Paper Towns',
#   'original_pub_year': '2008',
#   'avg_rating': 3.88,
#   'ratings_count': 461311},
#  {'author': 'William Goldman',
#   'original_title': 'The Princess Bride',
#   'original_pub_year': '1973',
#   'avg_rating': 4.25,
#   'ratings_count': 628637},
#  {'author': 'S.E. Hinton',
#   'original_title': 'The Outsiders',
#   'original_pub_year': '1967',
#   'avg_rating': 4.06,
#   'ratings_count': 659248},
#  {'author': 'James Dashner',
#   'original_title': 'The Maze Runner',
#   'original_pub_year': '2009',
#   'avg_rating': 4.02,
#   'ratings_count': 719925},
#  {'author': 'Steven D. Levitt, Stephen J. Dubner',
#   'original_title': 'Freakonomics: A Rogue Economist Explores the Hidden Side of Everything',
#   'original_pub_year': '2005',
#   'avg_rating': 3.93,
#   'ratings_count': 524191},
#  {'author': 'Frances Hodgson Burnett',
#   'original_title': 'The Secret Garden',
#   'original_pub_year': '1911',
#   'avg_rating': 4.12,
#   'ratings_count': 639357},
#  {'author': 'Gabriel García Márquez, Gregory Rabassa',
#   'original_title': 'Cien años de soledad',
#   'original_pub_year': '1967',
#   'avg_rating': 4.04,
#   'ratings_count': 490565},
#  {'author': 'Oscar Wilde, Jeffrey Eugenides',
#   'original_title': 'The Picture of Dorian Gray',
#   'original_pub_year': '1891',
#   'avg_rating': 4.06,
#   'ratings_count': 590014},
#  {'author': 'E.L. James',
#   'original_title': 'Fifty Shades Freed',
#   'original_pub_year': '2012',
#   'avg_rating': 3.88,
#   'ratings_count': 387290},
#  {'author': 'Bram Stoker, Nina Auerbach, David J. Skal',
#   'original_title': 'Dracula',
#   'original_pub_year': '1897',
#   'avg_rating': 3.98,
#   'ratings_count': 618973},
#  {'author': 'Stieg Larsson, Reg Keeland',
#   'original_title': 'Flickan som lekte med elden',
#   'original_pub_year': '2006',
#   'avg_rating': 4.22,
#   'ratings_count': 563994},
#  {'author': 'E.L. James',
#   'original_title': 'Fifty Shades Darker',
#   'original_pub_year': '2011',
#   'avg_rating': 3.87,
#   'ratings_count': 552059},
#  {'author': 'Barbara Kingsolver',
#   'original_title': 'The Poisonwood Bible',
#   'original_pub_year': '1998',
#   'avg_rating': 4.02,
#   'ratings_count': 546502},
#  {'author': 'David Sedaris',
#   'original_title': 'Me Talk Pretty One Day',
#   'original_pub_year': '2000',
#   'avg_rating': 3.97,
#   'ratings_count': 495736},
#  {'author': 'Maurice Sendak',
#   'original_title': 'Where the Wild Things Are',
#   'original_pub_year': '1963',
#   'avg_rating': 4.22,
#   'ratings_count': 620618},
#  {'author': 'Alexandre Dumas, Robin Buss',
#   'original_title': 'Le Comte de Monte-Cristo',
#   'original_pub_year': '1844',
#   'avg_rating': 4.21,
#   'ratings_count': 555822},
#  {'author': 'Cormac McCarthy',
#   'original_title': 'The Road',
#   'original_pub_year': '2006',
#   'avg_rating': 3.95,
#   'ratings_count': 504793},
#  {'author': 'Veronica Roth',
#   'original_title': 'Allegiant',
#   'original_pub_year': '2013',
#   'avg_rating': 3.63,
#   'ratings_count': 463257},
#  {'author': 'Tina Fey',
#   'original_title': 'Bossypants',
#   'original_pub_year': '2011',
#   'avg_rating': 3.94,
#   'ratings_count': 506250},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'A Walk to Remember',
#   'original_pub_year': '1999',
#   'avg_rating': 4.15,
#   'ratings_count': 546948},
#  {'author': 'Sophie Kinsella',
#   'original_title': 'Confessions of a Shopaholic',
#   'original_pub_year': '2000',
#   'avg_rating': 3.61,
#   'ratings_count': 543658},
#  {'author': 'Victor Hugo, Lee Fahnestock, Norman MacAfee',
#   'original_title': 'Les Misérables',
#   'original_pub_year': '1862',
#   'avg_rating': 4.14,
#   'ratings_count': 513407},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Clash of Kings',
#   'original_pub_year': '1998',
#   'avg_rating': 4.4,
#   'ratings_count': 523303},
#  {'author': 'Kim Edwards',
#   'original_title': "The Memory Keeper's Daughter",
#   'original_pub_year': '2005',
#   'avg_rating': 3.64,
#   'ratings_count': 501430},
#  {'author': 'Jojo Moyes',
#   'original_title': 'Me Before You',
#   'original_pub_year': '2012',
#   'avg_rating': 4.27,
#   'ratings_count': 587647},
#  {'author': 'Joseph Heller',
#   'original_title': 'Catch-22',
#   'original_pub_year': '1961',
#   'avg_rating': 3.98,
#   'ratings_count': 563265},
#  {'author': 'Mitch Albom, Saulius Dagys',
#   'original_title': 'Tuesdays with Morrie',
#   'original_pub_year': '1997',
#   'avg_rating': 4.06,
#   'ratings_count': 556518},
#  {'author': 'Jeffrey Eugenides',
#   'original_title': 'Middlesex',
#   'original_pub_year': '2002',
#   'avg_rating': 3.98,
#   'ratings_count': 488243},
#  {'author': 'Mark Twain, Guy Cardwell, John Seelye',
#   'original_title': 'The Adventures of Tom Sawyer',
#   'original_pub_year': '1876',
#   'avg_rating': 3.89,
#   'ratings_count': 555359},
#  {'author': "Madeleine L'Engle",
#   'original_title': 'A Wrinkle in Time',
#   'original_pub_year': '1962',
#   'avg_rating': 4.04,
#   'ratings_count': 615907},
#  {'author': 'Amy Tan',
#   'original_title': 'The Joy Luck Club',
#   'original_pub_year': '1989',
#   'avg_rating': 3.9,
#   'ratings_count': 515090},
#  {'author': 'Margaret Atwood',
#   'original_title': "The Handmaid's Tale",
#   'original_pub_year': '1985',
#   'avg_rating': 4.06,
#   'ratings_count': 607889},
#  {'author': 'Ann Brashares',
#   'original_title': 'The Sisterhood of the Traveling Pants',
#   'original_pub_year': '2001',
#   'avg_rating': 3.75,
#   'ratings_count': 525706},
#  {'author': 'Vladimir Nabokov, Craig Raine',
#   'original_title': 'Lolita',
#   'original_pub_year': '1955',
#   'avg_rating': 3.88,
#   'ratings_count': 469836},
#  {'author': 'Gregory Maguire, Douglas Smith',
#   'original_title': 'Wicked: The Life and Times of the Wicked Witch of the West',
#   'original_pub_year': '1995',
#   'avg_rating': 3.52,
#   'ratings_count': 506900},
#  {'author': 'John Grisham',
#   'original_title': 'The Firm',
#   'original_pub_year': '1991',
#   'avg_rating': 3.99,
#   'ratings_count': 488269},
#  {'author': 'Emma Donoghue',
#   'original_title': 'Room',
#   'original_pub_year': '2010',
#   'avg_rating': 4.03,
#   'ratings_count': 511360},
#  {'author': 'William Shakespeare, Richard Andrews, Rex Gibson',
#   'original_title': 'The Tragicall Historie of Hamlet, Prince of Denmark',
#   'original_pub_year': '1600',
#   'avg_rating': 4.0,
#   'ratings_count': 515820},
#  {'author': 'Frank Herbert',
#   'original_title': 'Dune',
#   'original_pub_year': '1965',
#   'avg_rating': 4.19,
#   'ratings_count': 485032},
#  {'author': 'Malcolm Gladwell',
#   'original_title': 'The Tipping Point: How Little Things Can Make a Big Difference',
#   'original_pub_year': '2000',
#   'avg_rating': 3.92,
#   'ratings_count': 490504},
#  {'author': 'Walter Isaacson',
#   'original_title': 'Steve Jobs',
#   'original_pub_year': '2011',
#   'avg_rating': 4.09,
#   'ratings_count': 560715},
#  {'author': 'Ken Kesey',
#   'original_title': "One Flew Over the Cuckoo's Nest",
#   'original_pub_year': '1962',
#   'avg_rating': 4.18,
#   'ratings_count': 491642},
#  {'author': 'Ernest Hemingway',
#   'original_title': 'The Old Man and the Sea',
#   'original_pub_year': '1952',
#   'avg_rating': 3.73,
#   'ratings_count': 520630},
#  {'author': 'John Steinbeck',
#   'original_title': 'The Grapes of Wrath',
#   'original_pub_year': '1939',
#   'avg_rating': 3.92,
#   'ratings_count': 322321},
#  {'author': 'Mitch Albom',
#   'original_title': 'The Five People You Meet in Heaven',
#   'original_pub_year': '2003',
#   'avg_rating': 3.9,
#   'ratings_count': 449501},
#  {'author': 'L.M. Montgomery',
#   'original_title': 'Anne of Green Gables',
#   'original_pub_year': '1908',
#   'avg_rating': 4.23,
#   'ratings_count': 502247},
#  {'author': 'Cassandra Clare',
#   'original_title': 'City of Glass',
#   'original_pub_year': '2009',
#   'avg_rating': 4.34,
#   'ratings_count': 593173},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Storm of Swords',
#   'original_pub_year': '2000',
#   'avg_rating': 4.54,
#   'ratings_count': 469022},
#  {'author': 'Rebecca Wells',
#   'original_title': 'Divine Secrets of the Ya-Ya Sisterhood',
#   'original_pub_year': '1996',
#   'avg_rating': 3.79,
#   'ratings_count': 465676},
#  {'author': 'Diana Gabaldon',
#   'original_title': 'Outlander',
#   'original_pub_year': '1991',
#   'avg_rating': 4.2,
#   'ratings_count': 515547},
#  {'author': 'Nathaniel Hawthorne, Thomas E. Connolly, Nina Baym',
#   'original_title': 'The Scarlet Letter',
#   'original_pub_year': '1850',
#   'avg_rating': 3.37,
#   'ratings_count': 509883},
#  {'author': 'Ransom Riggs',
#   'original_title': 'Miss Peregrine’s Home for Peculiar Children',
#   'original_pub_year': '2011',
#   'avg_rating': 3.89,
#   'ratings_count': 613674},
#  {'author': 'Stieg Larsson, Reg Keeland',
#   'original_title': 'Luftslottet som sprängdes',
#   'original_pub_year': '2007',
#   'avg_rating': 4.2,
#   'ratings_count': 443951},
#  {'author': 'Andy Weir',
#   'original_title': 'The Martian',
#   'original_pub_year': '2012',
#   'avg_rating': 4.39,
#   'ratings_count': 423344},
#  {'author': 'Ken Follett',
#   'original_title': 'The Pillars of the Earth',
#   'original_pub_year': '1989',
#   'avg_rating': 4.29,
#   'ratings_count': 462517},
#  {'author': 'Anthony Doerr',
#   'original_title': '',
#   'original_pub_year': '2014',
#   'avg_rating': 4.31,
#   'ratings_count': 470001},
#  {'author': 'Laura Hillenbrand',
#   'original_title': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   'original_pub_year': '2010',
#   'avg_rating': 4.4,
#   'ratings_count': 487775},
#  {'author': 'Dan Brown',
#   'original_title': 'Deception Point',
#   'original_pub_year': '2001',
#   'avg_rating': 3.67,
#   'ratings_count': 455610},
#  {'author': 'Donna Tartt',
#   'original_title': 'The Goldfinch',
#   'original_pub_year': '2013',
#   'avg_rating': 3.87,
#   'ratings_count': 396756},
#  {'author': 'Jay Asher',
#   'original_title': 'Thirteen Reasons Why',
#   'original_pub_year': '2007',
#   'avg_rating': 4.02,
#   'ratings_count': 463783},
#  {'author': 'Tracy Chevalier',
#   'original_title': 'Girl with a Pearl Earring',
#   'original_pub_year': '1999',
#   'avg_rating': 3.85,
#   'ratings_count': 467577},
#  {'author': 'Gayle Forman',
#   'original_title': 'If I Stay',
#   'original_pub_year': '2009',
#   'avg_rating': 3.96,
#   'ratings_count': 503527},
#  {'author': 'Anita Diamant',
#   'original_title': 'The Red Tent',
#   'original_pub_year': '1997',
#   'avg_rating': 4.16,
#   'ratings_count': 424981},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Sea of Monsters',
#   'original_pub_year': '2006',
#   'avg_rating': 4.23,
#   'ratings_count': 514932},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'Dear John',
#   'original_pub_year': '2006',
#   'avg_rating': 4.01,
#   'ratings_count': 441062},
#  {'author': 'Cassandra Clare',
#   'original_title': 'City of Ashes',
#   'original_pub_year': '2008',
#   'avg_rating': 4.21,
#   'ratings_count': 541117},
#  {'author': 'William Shakespeare',
#   'original_title': 'The Tragedy of Macbeth',
#   'original_pub_year': '1606',
#   'avg_rating': 3.88,
#   'ratings_count': 496018},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Two Towers',
#   'original_pub_year': '1954',
#   'avg_rating': 4.42,
#   'ratings_count': 480446},
#  {'author': 'Emily Giffin',
#   'original_title': 'Something Borrowed',
#   'original_pub_year': '2004',
#   'avg_rating': 3.83,
#   'ratings_count': 403601},
#  {'author': 'Dr. Seuss, לאה נאור',
#   'original_title': 'Green Eggs and Ham',
#   'original_pub_year': '1960',
#   'avg_rating': 4.29,
#   'ratings_count': 457475},
#  {'author': 'Roald Dahl, Quentin Blake',
#   'original_title': 'Charlie and the Chocolate Factory',
#   'original_pub_year': '1964',
#   'avg_rating': 4.1,
#   'ratings_count': 453959},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Battle of the Labyrinth',
#   'original_pub_year': '2008',
#   'avg_rating': 4.39,
#   'ratings_count': 508214},
#  {'author': 'Charles Dickens',
#   'original_title': 'Great Expectations',
#   'original_pub_year': '1860',
#   'avg_rating': 3.75,
#   'ratings_count': 459247},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Return of the King',
#   'original_pub_year': '1955',
#   'avg_rating': 4.51,
#   'ratings_count': 463959},
#  {'author': 'Albert Camus, Matthew    Ward',
#   'original_title': 'L’Étranger',
#   'original_pub_year': '1942',
#   'avg_rating': 3.96,
#   'ratings_count': 420600},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Lost Hero',
#   'original_pub_year': '2010',
#   'avg_rating': 4.35,
#   'ratings_count': 271576},
#  {'author': 'Rainbow Rowell',
#   'original_title': 'Eleanor & Park',
#   'original_pub_year': '2013',
#   'avg_rating': 4.11,
#   'ratings_count': 514312},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Feast for Crows',
#   'original_pub_year': '2005',
#   'avg_rating': 4.1,
#   'ratings_count': 428186},
#  {'author': 'Ally Condie',
#   'original_title': 'Matched',
#   'original_pub_year': '2010',
#   'avg_rating': 3.68,
#   'ratings_count': 511815},
#  {'author': 'Neil Gaiman',
#   'original_title': 'American Gods',
#   'original_pub_year': '2001',
#   'avg_rating': 4.11,
#   'ratings_count': 378019},
#  {'author': 'Stephen King, Bernie Wrightson',
#   'original_title': 'The Stand',
#   'original_pub_year': '1978',
#   'avg_rating': 4.34,
#   'ratings_count': 438832},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'The Last Song',
#   'original_pub_year': '2008',
#   'avg_rating': 4.14,
#   'ratings_count': 424637},
#  {'author': 'Dan Brown',
#   'original_title': 'Digital Fortress',
#   'original_pub_year': '1998',
#   'avg_rating': 3.6,
#   'ratings_count': 423019},
#  {'author': 'Jane Austen, Fiona Stafford',
#   'original_title': 'Emma',
#   'original_pub_year': '1815',
#   'avg_rating': 3.99,
#   'ratings_count': 459826},
#  {'author': 'Leo Tolstoy, Louise Maude, Leo Tolstoj, Aylmer Maude',
#   'original_title': 'Анна Каренина',
#   'original_pub_year': '1877',
#   'avg_rating': 4.02,
#   'ratings_count': 297472},
#  {'author': 'Anthony Burgess',
#   'original_title': 'A Clockwork Orange',
#   'original_pub_year': '1962',
#   'avg_rating': 3.98,
#   'ratings_count': 431195},
#  {'author': 'William Paul Young',
#   'original_title': 'The Shack: Where Tragedy Confronts Eternity',
#   'original_pub_year': '2007',
#   'avg_rating': 3.74,
#   'ratings_count': 419539},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Last Olympian',
#   'original_pub_year': '2009',
#   'avg_rating': 4.5,
#   'ratings_count': 397500},
#  {'author': 'Stephen King',
#   'original_title': 'It',
#   'original_pub_year': '1986',
#   'avg_rating': 4.18,
#   'ratings_count': 292592},
#  {'author': 'Fyodor Dostoyevsky, David McDuff',
#   'original_title': 'Преступление и наказание',
#   'original_pub_year': '1866',
#   'avg_rating': 4.18,
#   'ratings_count': 380903},
#  {'author': 'Sylvia Plath',
#   'original_title': 'The Bell Jar',
#   'original_pub_year': '1963',
#   'avg_rating': 3.98,
#   'ratings_count': 401605},
#  {'author': 'Frank McCourt',
#   'original_title': "Angela's Ashes: A Memoir",
#   'original_pub_year': '1996',
#   'avg_rating': 4.07,
#   'ratings_count': 392103},
#  {'author': 'Hermann Hesse, Hilda Rosner',
#   'original_title': 'Siddhartha',
#   'original_pub_year': '1922',
#   'avg_rating': 3.99,
#   'ratings_count': 372099},
#  {'author': 'Truman Capote',
#   'original_title': 'In Cold Blood',
#   'original_pub_year': '1965',
#   'avg_rating': 4.05,
#   'ratings_count': 381652},
#  {'author': 'Kami Garcia, Margaret Stohl',
#   'original_title': 'Beautiful Creatures',
#   'original_pub_year': '2009',
#   'avg_rating': 3.76,
#   'ratings_count': 436093},
#  {'author': 'Cassandra Clare',
#   'original_title': 'Clockwork Angel',
#   'original_pub_year': '2010',
#   'avg_rating': 4.33,
#   'ratings_count': 490890},
#  {'author': 'Roald Dahl, Quentin Blake',
#   'original_title': 'Matilda',
#   'original_pub_year': '1988',
#   'avg_rating': 4.29,
#   'ratings_count': 440743},
#  {'author': 'Erin Morgenstern',
#   'original_title': 'The Night Circus',
#   'original_pub_year': '2011',
#   'avg_rating': 4.03,
#   'ratings_count': 429543},
#  {'author': 'Philippa Gregory',
#   'original_title': 'The Other Boleyn Girl',
#   'original_pub_year': '2001',
#   'avg_rating': 4.04,
#   'ratings_count': 381080},
#  {'author': 'Scott Westerfeld',
#   'original_title': 'Uglies',
#   'original_pub_year': '2005',
#   'avg_rating': 3.86,
#   'ratings_count': 449073},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Dance with Dragons',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 365954},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Lord of the Rings',
#   'original_pub_year': '1955',
#   'avg_rating': 4.47,
#   'ratings_count': 389054},
#  {'author': 'Cheryl Strayed',
#   'original_title': 'Wild: From Lost to Found on the Pacific Crest Trail ',
#   'original_pub_year': '2012',
#   'avg_rating': 3.96,
#   'ratings_count': 379872},
#  {'author': 'Alan Moore, Dave Gibbons, John Higgins',
#   'original_title': 'Watchmen',
#   'original_pub_year': '1987',
#   'avg_rating': 4.35,
#   'ratings_count': 398018},
#  {'author': 'Patrick Rothfuss',
#   'original_title': 'The Name of the Wind',
#   'original_pub_year': '2007',
#   'avg_rating': 4.55,
#   'ratings_count': 400101},
#  {'author': 'Malcolm Gladwell',
#   'original_title': 'Outliers: The Story of Success',
#   'original_pub_year': '2008',
#   'avg_rating': 4.11,
#   'ratings_count': 353011},
#  {'author': 'Herman Melville, Andrew Delbanco, Tom Quirk',
#   'original_title': 'Moby Dick; or, The Whale',
#   'original_pub_year': '1851',
#   'avg_rating': 3.46,
#   'ratings_count': 358050},
#  {'author': 'Mary Ann Shaffer, Annie Barrows',
#   'original_title': 'The Guernsey Literary and Potato Peel Pie Society',
#   'original_pub_year': '2008',
#   'avg_rating': 4.12,
#   'ratings_count': 393626},
#  {'author': 'Chuck Palahniuk',
#   'original_title': 'Fight Club',
#   'original_pub_year': '1996',
#   'avg_rating': 4.2,
#   'ratings_count': 365349},
#  {'author': 'Charlaine Harris',
#   'original_title': 'Dead Until Dark',
#   'original_pub_year': '2001',
#   'avg_rating': 3.96,
#   'ratings_count': 420764},
#  {'author': 'Alice Walker',
#   'original_title': 'The Color Purple',
#   'original_pub_year': '1982',
#   'avg_rating': 4.17,
#   'ratings_count': 376766},
#  {'author': 'John Grogan',
#   'original_title': "Marley & Me: Life and Love with the World's Worst Dog",
#   'original_pub_year': '2005',
#   'avg_rating': 4.12,
#   'ratings_count': 367304},
#  {'author': 'Agatha Christie',
#   'original_title': 'Ten Little Niggers',
#   'original_pub_year': '1939',
#   'avg_rating': 4.23,
#   'ratings_count': 408983},
#  {'author': 'Dan Brown',
#   'original_title': 'The Lost Symbol',
#   'original_pub_year': '2009',
#   'avg_rating': 3.66,
#   'ratings_count': 369428},
#  {'author': 'Becca Fitzpatrick',
#   'original_title': 'Hush, Hush',
#   'original_pub_year': '2009',
#   'avg_rating': 4.0,
#   'ratings_count': 448166},
#  {'author': 'Jamie McGuire',
#   'original_title': 'Beautiful Disaster',
#   'original_pub_year': '2011',
#   'avg_rating': 4.15,
#   'ratings_count': 418309},
#  {'author': 'Charles Dickens',
#   'original_title': 'A Christmas Carol',
#   'original_pub_year': '1843',
#   'avg_rating': 4.02,
#   'ratings_count': 394540},
#  {'author': 'Anne Rice',
#   'original_title': 'Interview with the Vampire',
#   'original_pub_year': '1976',
#   'avg_rating': 3.97,
#   'ratings_count': 372566},
#  {'author': 'Kiera Cass',
#   'original_title': 'The Selection',
#   'original_pub_year': '2012',
#   'avg_rating': 4.15,
#   'ratings_count': 505340},
#  {'author': 'Janet Evanovich',
#   'original_title': 'One for the Money',
#   'original_pub_year': '1994',
#   'avg_rating': 4.03,
#   'ratings_count': 391007},
#  {'author': 'Rebecca Skloot',
#   'original_title': 'The Immortal Life of Henrietta Lacks',
#   'original_pub_year': '2010',
#   'avg_rating': 4.04,
#   'ratings_count': 377249},
#  {'author': 'Thomas Harris',
#   'original_title': 'The Silence of the Lambs',
#   'original_pub_year': '1988',
#   'avg_rating': 4.14,
#   'ratings_count': 351107},
#  {'author': 'Richelle Mead',
#   'original_title': '',
#   'original_pub_year': '2007',
#   'avg_rating': 4.14,
#   'ratings_count': 248283},
#  {'author': 'Malcolm Gladwell',
#   'original_title': 'Blink: The Power of Thinking Without Thinking',
#   'original_pub_year': '2005',
#   'avg_rating': 3.89,
#   'ratings_count': 348196},
#  {'author': 'Ian McEwan',
#   'original_title': 'Atonement',
#   'original_pub_year': '2001',
#   'avg_rating': 3.88,
#   'ratings_count': 347006},
#  {'author': 'Franz Kafka, Stanley Corngold',
#   'original_title': 'Die Verwandlung',
#   'original_pub_year': '1915',
#   'avg_rating': 3.78,
#   'ratings_count': 364933},
#  {'author': 'Rick Riordan',
#   'original_title': "The Titan's Curse",
#   'original_pub_year': '2007',
#   'avg_rating': 4.33,
#   'ratings_count': 446668},
#  {'author': 'Ernest Cline',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 349423},
#  {'author': 'Garth Stein',
#   'original_title': 'The Art of Racing in the Rain',
#   'original_pub_year': '2006',
#   'avg_rating': 4.19,
#   'ratings_count': 327409},
#  {'author': 'Erik Larson, Tony Goldwyn',
#   'original_title': 'The Devil in the White City: Murder, Magic, and Madness at the Fair that Changed America',
#   'original_pub_year': '2003',
#   'avg_rating': 3.98,
#   'ratings_count': 309385},
#  {'author': 'Sylvia Day',
#   'original_title': 'Bared to You',
#   'original_pub_year': '2012',
#   'avg_rating': 4.19,
#   'ratings_count': 222678},
#  {'author': 'C.S. Lewis, Pauline Baynes',
#   'original_title': 'The Chronicles of Narnia',
#   'original_pub_year': '1956',
#   'avg_rating': 4.24,
#   'ratings_count': 376385},
#  {'author': 'Mark Cotta Vaz',
#   'original_title': 'Twilight: The Complete Illustrated Movie Companion',
#   'original_pub_year': '',
#   'avg_rating': 4.23,
#   'ratings_count': 291411},
#  {'author': 'Dave Pelzer',
#   'original_title': 'A Child Called "It": One Child\'s Courage to Survive',
#   'original_pub_year': '1995',
#   'avg_rating': 4.08,
#   'ratings_count': 311543},
#  {'author': 'Robert Ludlum',
#   'original_title': 'The Bourne Identity',
#   'original_pub_year': '1980',
#   'avg_rating': 3.98,
#   'ratings_count': 327122},
#  {'author': 'Eoin Colfer',
#   'original_title': 'Artemis Fowl',
#   'original_pub_year': '2001',
#   'avg_rating': 3.82,
#   'ratings_count': 386923},
#  {'author': 'Lauren Kate',
#   'original_title': 'Fallen',
#   'original_pub_year': '2009',
#   'avg_rating': 3.74,
#   'ratings_count': 395296},
#  {'author': 'John Steinbeck',
#   'original_title': 'East of Eden  ',
#   'original_pub_year': '1952',
#   'avg_rating': 4.35,
#   'ratings_count': 320919},
#  {'author': 'Gillian Flynn',
#   'original_title': 'Dark Places',
#   'original_pub_year': '2009',
#   'avg_rating': 3.92,
#   'ratings_count': 333452},
#  {'author': 'John Grisham',
#   'original_title': 'The Client',
#   'original_pub_year': '1993',
#   'avg_rating': 3.97,
#   'ratings_count': 320083},
#  {'author': 'Emma McLaughlin, Nicola Kraus',
#   'original_title': 'The Nanny Diaries',
#   'original_pub_year': '2002',
#   'avg_rating': 3.4,
#   'ratings_count': 323762},
#  {'author': 'Lewis Carroll, John Tenniel, Martin Gardner',
#   'original_title': "Alice's Adventures in Wonderland",
#   'original_pub_year': '1865',
#   'avg_rating': 4.06,
#   'ratings_count': 340920},
#  {'author': 'Jane Austen, James Kinsley, Deidre Shauna Lynch',
#   'original_title': 'Persuasion',
#   'original_pub_year': '1817',
#   'avg_rating': 4.13,
#   'ratings_count': 365425},
#  {'author': 'Tatiana de Rosnay',
#   'original_title': "Elle s'appelait Sarah",
#   'original_pub_year': '2007',
#   'avg_rating': 4.14,
#   'ratings_count': 312444},
#  {'author': 'Stephen King',
#   'original_title': 'The Gunslinger',
#   'original_pub_year': '1982',
#   'avg_rating': 3.99,
#   'ratings_count': 332494},
#  {'author': 'Gabriel García Márquez, Edith Grossman',
#   'original_title': 'El amor en los tiempos del cólera',
#   'original_pub_year': '1985',
#   'avg_rating': 3.89,
#   'ratings_count': 283806},
#  {'author': 'Laurie Halse Anderson',
#   'original_title': 'Speak',
#   'original_pub_year': '1999',
#   'avg_rating': 4.0,
#   'ratings_count': 360156},
#  {'author': 'Liane Moriarty',
#   'original_title': "The Husband's Secret ",
#   'original_pub_year': '2013',
#   'avg_rating': 3.92,
#   'ratings_count': 232106},
#  {'author': 'Jon Krakauer',
#   'original_title': 'Into Thin Air: A Personal Account of the Mt. Everest Disaster',
#   'original_pub_year': '1997',
#   'avg_rating': 4.11,
#   'ratings_count': 291258},
#  {'author': 'Stephen King',
#   'original_title': 'Carrie',
#   'original_pub_year': '1974',
#   'avg_rating': 3.93,
#   'ratings_count': 356814},
#  {'author': 'Augusten Burroughs',
#   'original_title': 'Running with Scissors',
#   'original_pub_year': '2002',
#   'avg_rating': 3.7,
#   'ratings_count': 293878},
#  {'author': 'Max Brooks',
#   'original_title': 'World War Z: An Oral History of the Zombie War',
#   'original_pub_year': '2006',
#   'avg_rating': 4.01,
#   'ratings_count': 312969},
#  {'author': 'Dan Brown',
#   'original_title': 'Inferno',
#   'original_pub_year': '2013',
#   'avg_rating': 3.8,
#   'ratings_count': 287533},
#  {'author': 'Lois Lowry',
#   'original_title': 'Number the Stars',
#   'original_pub_year': '1989',
#   'avg_rating': 4.11,
#   'ratings_count': 333638},
#  {'author': 'James Patterson',
#   'original_title': 'Along Came a Spider',
#   'original_pub_year': '1993',
#   'avg_rating': 4.08,
#   'ratings_count': 311499},
#  {'author': 'Stephen King',
#   'original_title': 'Misery',
#   'original_pub_year': '1987',
#   'avg_rating': 4.11,
#   'ratings_count': 334647},
#  {'author': 'Gillian Flynn',
#   'original_title': 'Sharp Objects',
#   'original_pub_year': '2006',
#   'avg_rating': 3.92,
#   'ratings_count': 207889},
#  {'author': 'Katherine Paterson',
#   'original_title': 'Bridge to Terabithia',
#   'original_pub_year': '1977',
#   'avg_rating': 3.98,
#   'ratings_count': 337644},
#  {'author': 'P.C. Cast, Kristin Cast',
#   'original_title': 'Marked',
#   'original_pub_year': '2007',
#   'avg_rating': 3.79,
#   'ratings_count': 360044},
#  {'author': 'Stephen R. Covey',
#   'original_title': 'The 7 Habits of Highly Effective People',
#   'original_pub_year': '1989',
#   'avg_rating': 4.05,
#   'ratings_count': 314700},
#  {'author': 'William Shakespeare, Barbara A. Mowat, Paul Werstine, Catherine Belsey',
#   'original_title': "A Midsummer Night's Dream",
#   'original_pub_year': '1595',
#   'avg_rating': 3.94,
#   'ratings_count': 334241},
#  {'author': 'Jonathan Safran Foer',
#   'original_title': 'Extremely Loud and Incredibly Close',
#   'original_pub_year': '2005',
#   'avg_rating': 3.97,
#   'ratings_count': 294726},
#  {'author': 'R.J. Palacio',
#   'original_title': 'Wonder',
#   'original_pub_year': '2012',
#   'avg_rating': 4.43,
#   'ratings_count': 228538},
#  {'author': 'Dr. Seuss',
#   'original_title': 'The Cat in the Hat',
#   'original_pub_year': '1957',
#   'avg_rating': 4.15,
#   'ratings_count': 314016},
#  {'author': 'Marissa Meyer',
#   'original_title': 'Cinder',
#   'original_pub_year': '2012',
#   'avg_rating': 4.15,
#   'ratings_count': 427663},
#  {'author': 'Robert Galbraith, J.K. Rowling',
#   'original_title': "The Cuckoo's Calling",
#   'original_pub_year': '2013',
#   'avg_rating': 3.83,
#   'ratings_count': 297712},
#  {'author': 'Maggie Stiefvater',
#   'original_title': 'Shiver',
#   'original_pub_year': '2009',
#   'avg_rating': 3.78,
#   'ratings_count': 356625},
#  {'author': 'Ayn Rand, Leonard Peikoff',
#   'original_title': 'Atlas Shrugged',
#   'original_pub_year': '1957',
#   'avg_rating': 3.68,
#   'ratings_count': 283295},
#  {'author': 'Greg Mortenson, David Oliver Relin',
#   'original_title': 'Three Cups of Tea ',
#   'original_pub_year': '2006',
#   'avg_rating': 3.64,
#   'ratings_count': 283516},
#  {'author': 'Jane Carruth, Lewis Carroll, Rene Cloke',
#   'original_title': '',
#   'original_pub_year': '1865',
#   'avg_rating': 4.03,
#   'ratings_count': 343252},
#  {'author': 'Carlos Ruiz Zafón, Lucia Graves',
#   'original_title': 'La sombra del viento',
#   'original_pub_year': '2001',
#   'avg_rating': 4.24,
#   'ratings_count': 263685},
#  {'author': 'James Dashner',
#   'original_title': 'The Scorch Trials',
#   'original_pub_year': '2010',
#   'avg_rating': 3.93,
#   'ratings_count': 305643},
#  {'author': 'Dale Carnegie',
#   'original_title': 'How to Win Friends and Influence People',
#   'original_pub_year': '1936',
#   'avg_rating': 4.13,
#   'ratings_count': 282623},
#  {'author': 'Frances Mayes',
#   'original_title': 'Under the Tuscan Sun',
#   'original_pub_year': '1996',
#   'avg_rating': 3.72,
#   'ratings_count': 279264},
#  {'author': 'Liane Moriarty',
#   'original_title': 'Big Little Lies',
#   'original_pub_year': '2014',
#   'avg_rating': 4.2,
#   'ratings_count': 306186},
#  {'author': 'Gail Carson Levine',
#   'original_title': 'Ella Enchanted',
#   'original_pub_year': '1997',
#   'avg_rating': 3.97,
#   'ratings_count': 339117},
#  {'author': 'Ernest Hemingway',
#   'original_title': 'The Sun Also Rises',
#   'original_pub_year': '1926',
#   'avg_rating': 3.83,
#   'ratings_count': 284988},
#  {'author': 'Betty  Smith',
#   'original_title': 'A Tree Grows In Brooklyn ',
#   'original_pub_year': '1943',
#   'avg_rating': 4.24,
#   'ratings_count': 291909},
#  {'author': 'James Patterson',
#   'original_title': 'Kiss the Girls',
#   'original_pub_year': '1995',
#   'avg_rating': 3.93,
#   'ratings_count': 274639},
#  {'author': 'Kristin Hannah',
#   'original_title': 'The Nightingale',
#   'original_pub_year': '2015',
#   'avg_rating': 4.54,
#   'ratings_count': 253606},
#  {'author': 'Kazuo Ishiguro',
#   'original_title': 'Never Let Me Go',
#   'original_pub_year': '2005',
#   'avg_rating': 3.8,
#   'ratings_count': 294123},
#  {'author': 'Cecelia Ahern',
#   'original_title': 'PS, I Love You',
#   'original_pub_year': '2003',
#   'avg_rating': 4.01,
#   'ratings_count': 262921},
#  {'author': 'Daphne du Maurier, Sally Beauman',
#   'original_title': 'Rebecca',
#   'original_pub_year': '1938',
#   'avg_rating': 4.2,
#   'ratings_count': 177384},
#  {'author': 'Daniel Keyes',
#   'original_title': 'Flowers for Algernon',
#   'original_pub_year': '1966',
#   'avg_rating': 4.07,
#   'ratings_count': 313044},
#  {'author': 'Laura Esquivel, Thomas  Christensen, Carol Christensen',
#   'original_title': 'Como agua para chocolate',
#   'original_pub_year': '1989',
#   'avg_rating': 3.94,
#   'ratings_count': 263199},
#  {'author': 'Lisa See',
#   'original_title': 'Snow Flower and the Secret Fan',
#   'original_pub_year': '2005',
#   'avg_rating': 4.05,
#   'ratings_count': 280475},
#  {'author': 'Mario Puzo, Robert Thompson, Peter Bart',
#   'original_title': 'The Godfather',
#   'original_pub_year': '1969',
#   'avg_rating': 4.36,
#   'ratings_count': 256480},
#  {'author': 'John Green',
#   'original_title': 'An Abundance of Katherines',
#   'original_pub_year': '2006',
#   'avg_rating': 3.63,
#   'ratings_count': 312754},
#  {'author': 'Isaac Asimov',
#   'original_title': 'Foundation',
#   'original_pub_year': '1951',
#   'avg_rating': 4.13,
#   'ratings_count': 279688},
#  {'author': 'Neil Gaiman',
#   'original_title': 'The Ocean at the End of the Lane',
#   'original_pub_year': '2013',
#   'avg_rating': 3.99,
#   'ratings_count': 293844},
#  {'author': 'Shel Silverstein',
#   'original_title': 'A Light in the Attic',
#   'original_pub_year': '1981',
#   'avg_rating': 4.34,
#   'ratings_count': 297861},
#  {'author': 'John Tiffany, Jack Thorne, J.K. Rowling',
#   'original_title': 'Harry Potter and the Cursed Child, Parts One and Two',
#   'original_pub_year': '2016',
#   'avg_rating': 3.75,
#   'ratings_count': 270603},
#  {'author': 'Lauren Oliver',
#   'original_title': 'Delirium',
#   'original_pub_year': '2011',
#   'avg_rating': 3.99,
#   'ratings_count': 256975},
#  {'author': 'John Grisham',
#   'original_title': 'The Pelican Brief',
#   'original_pub_year': '1992',
#   'avg_rating': 3.95,
#   'ratings_count': 288376},
#  {'author': 'Neil Gaiman',
#   'original_title': 'Coraline',
#   'original_pub_year': '2002',
#   'avg_rating': 4.03,
#   'ratings_count': 316379},
#  {'author': 'Terry Pratchett, Neil Gaiman',
#   'original_title': 'Good Omens: The Nice and Accurate Prophecies of Agnes Nutter, Witch',
#   'original_pub_year': '1990',
#   'avg_rating': 4.25,
#   'ratings_count': 298304},
#  {'author': 'Jack Kerouac',
#   'original_title': 'On the Road',
#   'original_pub_year': '1955',
#   'avg_rating': 3.64,
#   'ratings_count': 246602},
#  {'author': 'Graeme Simsion',
#   'original_title': 'The Rosie Project',
#   'original_pub_year': '2013',
#   'avg_rating': 4.01,
#   'ratings_count': 251703},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'The Lucky One',
#   'original_pub_year': '2008',
#   'avg_rating': 4.1,
#   'ratings_count': 267166},
#  {'author': 'Ayn Rand, Leonard Peikoff',
#   'original_title': 'The Fountainhead',
#   'original_pub_year': '1943',
#   'avg_rating': 3.85,
#   'ratings_count': 244545},
#  {'author': 'Tom Clancy',
#   'original_title': 'The Hunt for Red October',
#   'original_pub_year': '1984',
#   'avg_rating': 4.01,
#   'ratings_count': 270318},
#  {'author': 'Richard Adams',
#   'original_title': 'Watership Down',
#   'original_pub_year': '1972',
#   'avg_rating': 4.05,
#   'ratings_count': 292426},
#  {'author': 'Mindy Kaling',
#   'original_title': 'Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   'original_pub_year': '2011',
#   'avg_rating': 3.84,
#   'ratings_count': 290674},
#  {'author': 'Abraham Verghese',
#   'original_title': 'Cutting for Stone',
#   'original_pub_year': '2009',
#   'avg_rating': 4.28,
#   'ratings_count': 258319},
#  {'author': 'C.S. Lewis, Pauline Baynes',
#   'original_title': 'The Voyage of the Dawn Treader',
#   'original_pub_year': '1951',
#   'avg_rating': 4.08,
#   'ratings_count': 306492},
#  {'author': 'Robert Louis Stevenson',
#   'original_title': 'Treasure Island',
#   'original_pub_year': '1882',
#   'avg_rating': 3.82,
#   'ratings_count': 268012},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Son of Neptune ',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 299980},
#  {'author': 'Stephen King',
#   'original_title': '11/22/63',
#   'original_pub_year': '2011',
#   'avg_rating': 4.29,
#   'ratings_count': 258464},
#  {'author': 'Eric Carle',
#   'original_title': 'The Very Hungry Caterpillar',
#   'original_pub_year': '1969',
#   'avg_rating': 4.29,
#   'ratings_count': 296952},
#  {'author': 'Kurt Vonnegut Jr.',
#   'original_title': "Cat's Cradle",
#   'original_pub_year': '1963',
#   'avg_rating': 4.18,
#   'ratings_count': 238940},
#  {'author': 'H.G. Wells, Greg Bear, Carlo Pagetti',
#   'original_title': 'The Time Machine',
#   'original_pub_year': '1895',
#   'avg_rating': 3.87,
#   'ratings_count': 276076},
#  {'author': 'Todd Burpo, Lynn Vincent',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.01,
#   'ratings_count': 228371},
# ...
#   'avg_rating': 3.93,
#   'ratings_count': 102646},
#  {'author': 'Richard Dawkins',
#   'original_title': 'The Selfish Gene',
#   'original_pub_year': '1976',
#   'avg_rating': 4.11,
#   'ratings_count': 96564},
#  {'author': 'Geraldine Brooks',
#   'original_title': 'Year of Wonders: A Novel of the Plague',
#   'original_pub_year': '2001',
#   'avg_rating': 4.0,
#   'ratings_count': 104283},
#  {'author': 'Michael Connelly',
#   'original_title': 'The Black Echo',
#   'original_pub_year': '1992',
#   'avg_rating': 4.08,
#   'ratings_count': 98591},
#  {'author': 'Ayn Rand',
#   'original_title': 'Anthem',
#   'original_pub_year': '1938',
#   'avg_rating': 3.62,
#   'ratings_count': 95620},
#  {'author': 'Sylvain Reynard',
#   'original_title': "Gabriel's Inferno",
#   'original_pub_year': '2011',
#   'avg_rating': 4.02,
#   'ratings_count': 119633},
#  {'author': 'Judi Barrett, Ron Barrett',
#   'original_title': 'Cloudy with a Chance of Meatballs',
#   'original_pub_year': '1978',
#   'avg_rating': 4.15,
#   'ratings_count': 104677},
#  {'author': 'Helen Simonson',
#   'original_title': "Major Pettigrew's Last Stand",
#   'original_pub_year': '2010',
#   'avg_rating': 3.87,
#   'ratings_count': 97745},
#  {'author': 'Nora Roberts',
#   'original_title': 'Vision in White',
#   'original_pub_year': '2009',
#   'avg_rating': 4.1,
#   'ratings_count': 103933},
#  {'author': 'Jodi Picoult',
#   'original_title': 'The Tenth Circle',
#   'original_pub_year': '2006',
#   'avg_rating': 3.48,
#   'ratings_count': 99170},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Throne of Fire',
#   'original_pub_year': '2011',
#   'avg_rating': 4.2,
#   'ratings_count': 116360},
#  {'author': 'John Scalzi',
#   'original_title': "Old Man's War",
#   'original_pub_year': '2005',
#   'avg_rating': 4.23,
#   'ratings_count': 97653},
#  {'author': 'Stephen King',
#   'original_title': "Gerald's Game",
#   'original_pub_year': '1992',
#   'avg_rating': 3.47,
#   'ratings_count': 100158},
#  {'author': 'Janet Evanovich',
#   'original_title': 'Two for the Dough',
#   'original_pub_year': '1996',
#   'avg_rating': 4.11,
#   'ratings_count': 116171},
#  {'author': 'Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker',
#   'original_title': 'The Joy of Cooking',
#   'original_pub_year': '1931',
#   'avg_rating': 4.14,
#   'ratings_count': 102348},
#  {'author': 'Joe Haldeman',
#   'original_title': 'The Forever War',
#   'original_pub_year': '1974',
#   'avg_rating': 4.15,
#   'ratings_count': 87636},
#  {'author': 'Stephen King, Bettina Blanch Tyroller',
#   'original_title': 'Insomnia',
#   'original_pub_year': '1994',
#   'avg_rating': 3.79,
#   'ratings_count': 100972},
#  {'author': 'Azar Nafisi',
#   'original_title': 'Reading Lolita in Tehran: A Memoir in Books',
#   'original_pub_year': '2003',
#   'avg_rating': 3.57,
#   'ratings_count': 94696},
#  {'author': 'Joe Abercrombie',
#   'original_title': 'The Blade Itself',
#   'original_pub_year': '2006',
#   'avg_rating': 4.14,
#   'ratings_count': 97501},
#  {'author': 'Eoin Colfer',
#   'original_title': 'The Arctic Incident',
#   'original_pub_year': '2002',
#   'avg_rating': 3.94,
#   'ratings_count': 108031},
#  {'author': 'Annie Proulx',
#   'original_title': 'The Shipping News',
#   'original_pub_year': '1993',
#   'avg_rating': 3.83,
#   'ratings_count': 103151},
#  {'author': 'Marie Kondō, Cathy Hirano',
#   'original_title': '人生がときめく片づけの魔法',
#   'original_pub_year': '2011',
#   'avg_rating': 3.77,
#   'ratings_count': 105063},
#  {'author': 'Jennifer Niven, فرانک معنوی',
#   'original_title': 'All the Bright Places',
#   'original_pub_year': '2015',
#   'avg_rating': 4.19,
#   'ratings_count': 132087},
#  {'author': 'Kathy Reichs',
#   'original_title': 'Déjà Dead',
#   'original_pub_year': '1997',
#   'avg_rating': 3.86,
#   'ratings_count': 100369},
#  {'author': 'Michael Scott',
#   'original_title': 'The Alchemyst: The Secrets of The Immortal Nicholas Flamel',
#   'original_pub_year': '2007',
#   'avg_rating': 3.84,
#   'ratings_count': 58396},
#  {'author': 'Jeffrey Eugenides',
#   'original_title': 'The Marriage Plot',
#   'original_pub_year': '2011',
#   'avg_rating': 3.42,
#   'ratings_count': 90551},
#  {'author': 'Isabel Allende, Margaret Sayers Peden',
#   'original_title': 'Hija de la fortuna',
#   'original_pub_year': '1998',
#   'avg_rating': 3.89,
#   'ratings_count': 89770},
#  {'author': 'Jessica Knoll',
#   'original_title': 'Luckiest Girl Alive',
#   'original_pub_year': '2015',
#   'avg_rating': 3.48,
#   'ratings_count': 82504},
#  {'author': 'Ellen Hopkins',
#   'original_title': 'Crank (Crank, #1)',
#   'original_pub_year': '2004',
#   'avg_rating': 4.16,
#   'ratings_count': 104168},
#  {'author': 'Maggie Stiefvater',
#   'original_title': 'The Raven Boys',
#   'original_pub_year': '2012',
#   'avg_rating': 4.05,
#   'ratings_count': 121727},
#  {'author': 'Richard Matheson',
#   'original_title': 'I Am Legend and Other Stories',
#   'original_pub_year': '1954',
#   'avg_rating': 3.99,
#   'ratings_count': 98795},
#  {'author': 'Elizabeth Strout',
#   'original_title': 'Olive Kitteridge',
#   'original_pub_year': '2008',
#   'avg_rating': 3.78,
#   'ratings_count': 85019},
#  {'author': 'Lena Dunham, Joana Avillez',
#   'original_title': 'Not that Kind of Girl',
#   'original_pub_year': '2014',
#   'avg_rating': 3.33,
#   'ratings_count': 88251},
#  {'author': 'James C. Collins',
#   'original_title': "Good to Great: Why Some Companies Make the Leap... and Others Don't",
#   'original_pub_year': '2001',
#   'avg_rating': 4.04,
#   'ratings_count': 85277},
#  {'author': 'Kristin Cashore',
#   'original_title': 'Fire',
#   'original_pub_year': '2009',
#   'avg_rating': 4.12,
#   'ratings_count': 98180},
#  {'author': 'Samuel Beckett',
#   'original_title': 'En attendant Godot',
#   'original_pub_year': '1952',
#   'avg_rating': 3.81,
#   'ratings_count': 98950},
#  {'author': 'Jack London',
#   'original_title': 'White Fang',
#   'original_pub_year': '1906',
#   'avg_rating': 3.94,
#   'ratings_count': 100223},
#  {'author': 'Stephen King, Bernie Wrightson',
#   'original_title': 'Wolves of the Calla',
#   'original_pub_year': '2003',
#   'avg_rating': 4.17,
#   'ratings_count': 98182},
#  {'author': 'Philip Pullman',
#   'original_title': 'His Dark Materials',
#   'original_pub_year': '2000',
#   'avg_rating': 4.25,
#   'ratings_count': 88227},
#  {'author': 'J.A. Redmerski',
#   'original_title': 'The Edge of Never',
#   'original_pub_year': '2012',
#   'avg_rating': 4.26,
#   'ratings_count': 117508},
#  {'author': 'Kimberly McCreight',
#   'original_title': 'Reconstructing Amelia',
#   'original_pub_year': '2013',
#   'avg_rating': 3.82,
#   'ratings_count': 86965},
#  {'author': 'Jojo Moyes',
#   'original_title': 'The One Plus One',
#   'original_pub_year': '2014',
#   'avg_rating': 3.94,
#   'ratings_count': 87412},
#  {'author': 'Michael Cunningham',
#   'original_title': 'The Hours',
#   'original_pub_year': '1998',
#   'avg_rating': 3.91,
#   'ratings_count': 97462},
#  {'author': 'Alice Clayton',
#   'original_title': 'Wallbanger',
#   'original_pub_year': '2012',
#   'avg_rating': 4.1,
#   'ratings_count': 134805},
#  {'author': 'David Sedaris',
#   'original_title': 'Holidays on Ice',
#   'original_pub_year': '1997',
#   'avg_rating': 3.95,
#   'ratings_count': 82591},
#  {'author': 'Stephen King',
#   'original_title': 'Desperation',
#   'original_pub_year': '1996',
#   'avg_rating': 3.8,
#   'ratings_count': 94821},
#  {'author': 'Lauren Kate',
#   'original_title': 'Passion',
#   'original_pub_year': '2011',
#   'avg_rating': 3.89,
#   'ratings_count': 119735},
#  {'author': 'James Dashner',
#   'original_title': 'The Kill Order',
#   'original_pub_year': '2012',
#   'avg_rating': 3.69,
#   'ratings_count': 96568},
#  {'author': 'Susan Ee',
#   'original_title': 'Angelfall',
#   'original_pub_year': '2011',
#   'avg_rating': 4.19,
#   'ratings_count': 73886},
#  {'author': 'Richard Russo',
#   'original_title': 'Empire Falls',
#   'original_pub_year': '2001',
#   'avg_rating': 3.91,
#   'ratings_count': 90811},
#  {'author': 'Robert Jordan',
#   'original_title': 'The Fires of Heaven',
#   'original_pub_year': '1993',
#   'avg_rating': 4.13,
#   'ratings_count': 93227},
#  {'author': 'Jandy Nelson',
#   'original_title': "I'll Give You the Sun",
#   'original_pub_year': '2014',
#   'avg_rating': 4.14,
#   'ratings_count': 140937},
#  {'author': 'Chuck Palahniuk',
#   'original_title': 'Survivor',
#   'original_pub_year': '1999',
#   'avg_rating': 3.93,
#   'ratings_count': 49551},
#  {'author': 'Sophie Kinsella',
#   'original_title': 'Shopaholic and Baby',
#   'original_pub_year': '2007',
#   'avg_rating': 3.77,
#   'ratings_count': 98130},
#  {'author': 'Stephen King',
#   'original_title': 'The Dark Tower',
#   'original_pub_year': '2004',
#   'avg_rating': 4.27,
#   'ratings_count': 93296},
#  {'author': 'Catherine Hardwicke',
#   'original_title': "Twilight Director's Notebook",
#   'original_pub_year': '2009',
#   'avg_rating': 4.2,
#   'ratings_count': 88847},
#  {'author': 'Sophie Kinsella',
#   'original_title': 'Shopaholic Abroad',
#   'original_pub_year': '2001',
#   'avg_rating': 3.75,
#   'ratings_count': 93498},
#  {'author': 'Richard Feynman',
#   'original_title': "Surely You're Joking, Mr. Feynman! Adventures of a Curious Character",
#   'original_pub_year': '1984',
#   'avg_rating': 4.29,
#   'ratings_count': 91625},
#  {'author': 'Maggie Stiefvater',
#   'original_title': 'Linger',
#   'original_pub_year': '2010',
#   'avg_rating': 3.91,
#   'ratings_count': 125363},
#  {'author': 'L.M. Montgomery',
#   'original_title': 'The Complete Anne of Green Gables Boxed Set',
#   'original_pub_year': '1908',
#   'avg_rating': 4.42,
#   'ratings_count': 92142},
#  {'author': 'James Joyce, Seamus Deane',
#   'original_title': 'A Portrait of the Artist as a Young Man',
#   'original_pub_year': '1916',
#   'avg_rating': 3.6,
#   'ratings_count': 92569},
#  {'author': 'Robert Jordan, Brandon Sanderson',
#   'original_title': 'The Gathering Storm',
#   'original_pub_year': '2009',
#   'avg_rating': 4.34,
#   'ratings_count': 94095},
#  {'author': 'George Eliot, Michel Faber',
#   'original_title': 'Middlemarch',
#   'original_pub_year': '1871',
#   'avg_rating': 3.93,
#   'ratings_count': 95995},
#  {'author': 'Colleen Hoover',
#   'original_title': 'Point of Retreat',
#   'original_pub_year': '2012',
#   'avg_rating': 4.3,
#   'ratings_count': 109344},
#  {'author': 'John Grisham',
#   'original_title': 'The Partner',
#   'original_pub_year': '1997',
#   'avg_rating': 3.89,
#   'ratings_count': 86870},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Hobbit and The Lord of the Rings',
#   'original_pub_year': '1973',
#   'avg_rating': 4.59,
#   'ratings_count': 90907},
#  {'author': 'S.C. Stephens',
#   'original_title': 'Thoughtless',
#   'original_pub_year': '2009',
#   'avg_rating': 4.12,
#   'ratings_count': 90483},
#  {'author': 'Scott Turow',
#   'original_title': 'Presumed Innocent',
#   'original_pub_year': '1986',
#   'avg_rating': 4.1,
#   'ratings_count': 91774},
#  {'author': 'Stephen King',
#   'original_title': 'The Dark Half',
#   'original_pub_year': '1989',
#   'avg_rating': 3.74,
#   'ratings_count': 94624},
#  {'author': 'Stacy Schiff',
#   'original_title': 'Cleopatra: A Life',
#   'original_pub_year': '2006',
#   'avg_rating': 3.62,
#   'ratings_count': 73994},
#  {'author': 'Thomas L. Friedman',
#   'original_title': 'The World Is Flat: A Brief History of the Twenty-first Century',
#   'original_pub_year': '2005',
#   'avg_rating': 3.66,
#   'ratings_count': 78271},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'Steelheart',
#   'original_pub_year': '2013',
#   'avg_rating': 4.16,
#   'ratings_count': 76261},
#  {'author': 'Marcus Pfister, J. Alison James',
#   'original_title': '',
#   'original_pub_year': '1995',
#   'avg_rating': 4.15,
#   'ratings_count': 95421},
#  {'author': 'Jules Verne',
#   'original_title': 'Voyage au centre de la Terre',
#   'original_pub_year': '1864',
#   'avg_rating': 3.84,
#   'ratings_count': 89410},
#  {'author': 'Gretchen Rubin',
#   'original_title': 'The Happiness Project',
#   'original_pub_year': '2009',
#   'avg_rating': 3.57,
#   'ratings_count': 94456},
#  {'author': 'Philip K. Dick',
#   'original_title': 'The Man in the High Castle',
#   'original_pub_year': '1962',
#   'avg_rating': 3.66,
#   'ratings_count': 84180},
#  {'author': 'Vincent Bugliosi, Curt Gentry',
#   'original_title': 'Helter Skelter: The True Story of The Manson Murders',
#   'original_pub_year': '1974',
#   'avg_rating': 4.0,
#   'ratings_count': 92158},
#  {'author': 'Robert Kapilow, Dr. Seuss',
#   'original_title': '',
#   'original_pub_year': '',
#   'avg_rating': 4.44,
#   'ratings_count': 90574},
#  {'author': 'Dante Alighieri, Anthony M. Esolen',
#   'original_title': 'Inferno',
#   'original_pub_year': '1320',
#   'avg_rating': 3.99,
#   'ratings_count': 87511},
#  {'author': 'Deborah Harkness',
#   'original_title': 'Shadow of Night',
#   'original_pub_year': '2012',
#   'avg_rating': 4.04,
#   'ratings_count': 97925},
#  {'author': 'Jodi Picoult',
#   'original_title': 'Leaving Time',
#   'original_pub_year': '2014',
#   'avg_rating': 3.94,
#   'ratings_count': 76553},
#  {'author': 'Patricia Briggs',
#   'original_title': 'Moon Called',
#   'original_pub_year': '2006',
#   'avg_rating': 4.18,
#   'ratings_count': 129150},
#  {'author': 'Melissa de la Cruz',
#   'original_title': 'Blue Bloods',
#   'original_pub_year': '2006',
#   'avg_rating': 3.68,
#   'ratings_count': 116687},
#  {'author': 'Caleb Carr',
#   'original_title': 'The Alienist',
#   'original_pub_year': '1994',
#   'avg_rating': 4.05,
#   'ratings_count': 96981},
#  {'author': 'Ta-Nehisi Coates',
#   'original_title': 'Between the World and Me',
#   'original_pub_year': '2015',
#   'avg_rating': 4.4,
#   'ratings_count': 74218},
#  {'author': 'John Milton, John      Leonard',
#   'original_title': 'Paradise Lost',
#   'original_pub_year': '1667',
#   'avg_rating': 3.8,
#   'ratings_count': 96316},
#  {'author': 'Michael   Lewis',
#   'original_title': 'The Big Short: Inside the Doomsday Machine',
#   'original_pub_year': '2009',
#   'avg_rating': 4.26,
#   'ratings_count': 37090},
#  {'author': 'Stephen King',
#   'original_title': 'The Girl Who Loved Tom Gordon',
#   'original_pub_year': '1999',
#   'avg_rating': 3.56,
#   'ratings_count': 95768},
#  {'author': 'Patrick Ness, Jim Kay, Siobhan Dowd',
#   'original_title': ' A Monster Calls ',
#   'original_pub_year': '2011',
#   'avg_rating': 4.36,
#   'ratings_count': 104579},
#  {'author': 'Robert Jordan, Brandon Sanderson',
#   'original_title': 'Towers of Midnight',
#   'original_pub_year': '2010',
#   'avg_rating': 4.42,
#   'ratings_count': 91383},
#  {'author': 'Frederick Forsyth',
#   'original_title': 'The Day of the Jackal',
#   'original_pub_year': '1971',
#   'avg_rating': 4.25,
#   'ratings_count': 85883},
#  {'author': 'Jason Fried, David Heinemeier Hansson',
#   'original_title': 'Rework',
#   'original_pub_year': '2010',
#   'avg_rating': 3.93,
#   'ratings_count': 88626},
#  {'author': 'Rainbow Rowell',
#   'original_title': 'Attachments',
#   'original_pub_year': '2011',
#   'avg_rating': 3.95,
#   'ratings_count': 105414},
#  {'author': 'Stephenie Meyer, Ilyana Kadushin, Matt Walters',
#   'original_title': 'The Twilight Saga',
#   'original_pub_year': '2005',
#   'avg_rating': 3.88,
#   'ratings_count': 89204},
#  {'author': 'Carol Rifka Brunt',
#   'original_title': "Tell the Wolves I'm Home",
#   'original_pub_year': '2012',
#   'avg_rating': 4.04,
#   'ratings_count': 85582},
#  {'author': 'James Herriot',
#   'original_title': 'All Creatures Great And Small',
#   'original_pub_year': '1972',
#   'avg_rating': 4.31,
#   'ratings_count': 64779},
#  {'author': 'Michelle Hodkin',
#   'original_title': 'The Unbecoming of Mara Dyer',
#   'original_pub_year': '2011',
#   'avg_rating': 4.09,
#   'ratings_count': 83847},
#  {'author': 'Janet Evanovich',
#   'original_title': 'Three to Get Deadly',
#   'original_pub_year': '1997',
#   'avg_rating': 4.14,
#   'ratings_count': 113400},
#  {'author': 'Emmuska Orczy',
#   'original_title': 'The Scarlet Pimpernel',
#   'original_pub_year': '1905',
#   'avg_rating': 4.06,
#   'ratings_count': 93217},
#  {'author': 'Jon Stone, Michael J. Smollin',
#   'original_title': 'The Monster at the End of This Book',
#   'original_pub_year': '1971',
#   'avg_rating': 4.45,
#   'ratings_count': 102184},
#  {'author': 'Judy Blume',
#   'original_title': 'Tales of a Fourth Grade Nothing',
#   'original_pub_year': '1972',
#   'avg_rating': 4.09,
#   'ratings_count': 106435},
#  {'author': 'Leigh Bardugo',
#   'original_title': 'Shadow and Bone',
#   'original_pub_year': '2012',
#   'avg_rating': 4.05,
#   'ratings_count': 135225},
#  ...]

# %%
c = sorted(l, key = lambda x: x['avg_rating'],reverse=True)

# %%
c
# Out:
# [{'author': 'Bill Watterson',
#   'original_title': 'The Complete Calvin and Hobbes',
#   'original_pub_year': '2005',
#   'avg_rating': 4.82,
#   'ratings_count': 28900},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'Words of Radiance',
#   'original_pub_year': '2014',
#   'avg_rating': 4.77,
#   'ratings_count': 73572},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': '',
#   'original_pub_year': '2003',
#   'avg_rating': 4.77,
#   'ratings_count': 33220},
#  {'author': 'Anonymous, Lane T. Dennis, Wayne A. Grudem',
#   'original_title': '',
#   'original_pub_year': '2002',
#   'avg_rating': 4.76,
#   'ratings_count': 8953},
#  {'author': 'Francine Rivers',
#   'original_title': 'Mark of the Lion Trilogy',
#   'original_pub_year': '1993',
#   'avg_rating': 4.76,
#   'ratings_count': 9081},
#  {'author': 'Bill Watterson',
#   'original_title': "It's a Magical World: A Calvin and Hobbes Collection",
#   'original_pub_year': '1996',
#   'avg_rating': 4.75,
#   'ratings_count': 22351},
#  {'author': 'J.K. Rowling',
#   'original_title': 'Complete Harry Potter Boxed Set',
#   'original_pub_year': '1998',
#   'avg_rating': 4.74,
#   'ratings_count': 190050},
#  {'author': 'Bill Watterson',
#   'original_title': "There's Treasure Everywhere: A Calvin and Hobbes Collection",
#   'original_pub_year': '1996',
#   'avg_rating': 4.74,
#   'ratings_count': 16766},
#  {'author': 'J.K. Rowling',
#   'original_title': 'Harry Potter Collection (Harry Potter, #1-6)',
#   'original_pub_year': '2005',
#   'avg_rating': 4.73,
#   'ratings_count': 24618},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Authoritative Calvin and Hobbes',
#   'original_pub_year': '1990',
#   'avg_rating': 4.73,
#   'ratings_count': 16087},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Indispensable Calvin and Hobbes: A Calvin and Hobbes Treasury',
#   'original_pub_year': '1992',
#   'avg_rating': 4.73,
#   'ratings_count': 14597},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'A Court of Mist and Fury',
#   'original_pub_year': '2016',
#   'avg_rating': 4.72,
#   'ratings_count': 108384},
#  {'author': 'Bill Watterson',
#   'original_title': 'Attack of the Deranged Mutant Killer Monster Snow Goons: A Calvin and Hobbes Collection',
#   'original_pub_year': '1992',
#   'avg_rating': 4.72,
#   'ratings_count': 9713},
#  {'author': 'Bill Watterson',
#   'original_title': 'Homicidal Psycho Jungle Cat: A Calvin and Hobbes Collection',
#   'original_pub_year': '1994',
#   'avg_rating': 4.71,
#   'ratings_count': 14113},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Revenge of the Baby-Sat: A Calvin and Hobbes Collection',
#   'original_pub_year': '1991',
#   'avg_rating': 4.71,
#   'ratings_count': 11503},
#  {'author': 'The Church of Jesus Christ of Latter-day Saints',
#   'original_title': 'Preach My Gospel (A Guide to Missionary Service)',
#   'original_pub_year': '2004',
#   'avg_rating': 4.71,
#   'ratings_count': 9891},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Days Are Just Packed: A Calvin and Hobbes Collection',
#   'original_pub_year': '1993',
#   'avg_rating': 4.68,
#   'ratings_count': 19143},
#  {'author': 'Anonymous, Ronald A. Beers, Ronald A. Beers',
#   'original_title': '',
#   'original_pub_year': '1992',
#   'avg_rating': 4.67,
#   'ratings_count': 13614},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'The Way of Kings, Part 1',
#   'original_pub_year': '2011',
#   'avg_rating': 4.67,
#   'ratings_count': 9792},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter Boxed Set Books 1-4',
#   'original_pub_year': '1999',
#   'avg_rating': 4.66,
#   'ratings_count': 43929},
#  {'author': 'Anonymous',
#   'original_title': 'Holy Bible English Standard Version',
#   'original_pub_year': '2001',
#   'avg_rating': 4.66,
#   'ratings_count': 17863},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Calvin and Hobbes Lazy Sunday Book',
#   'original_pub_year': '1989',
#   'avg_rating': 4.66,
#   'ratings_count': 18641},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Essential Calvin and Hobbes: A Calvin and Hobbes Treasury',
#   'original_pub_year': '1988',
#   'avg_rating': 4.65,
#   'ratings_count': 93001},
#  {'author': 'Daniel Abraham, George R.R. Martin, Tommy Patterson',
#   'original_title': 'A Song of Ice and Fire Graphic Novels',
#   'original_pub_year': '2011',
#   'avg_rating': 4.65,
#   'ratings_count': 18667},
#  {'author': 'Neil Gaiman, Mike Dringenberg, Chris Bachalo, Michael Zulli, Kelly Jones, Charles Vess, Colleen Doran, Malcolm Jones III, Steve Parkhouse, Daniel Vozzo, Lee Loughridge, Steve Oliff, Todd Klein, Dave McKean, Sam Kieth',
#   'original_title': 'The Absolute Sandman, Volume One',
#   'original_pub_year': '2006',
#   'avg_rating': 4.65,
#   'ratings_count': 13401},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'The Way of Kings',
#   'original_pub_year': '2010',
#   'avg_rating': 4.64,
#   'ratings_count': 144822},
#  {'author': 'Bill Watterson',
#   'original_title': 'The Calvin and Hobbes Tenth Anniversary Book',
#   'original_pub_year': '1995',
#   'avg_rating': 4.63,
#   'ratings_count': 48280},
#  {'author': 'George R.R. Martin',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.63,
#   'ratings_count': 28654},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Song of Ice and Fire',
#   'original_pub_year': '2000',
#   'avg_rating': 4.63,
#   'ratings_count': 20567},
#  {'author': 'James E. Talmage',
#   'original_title': 'Jesus the Christ: A Study of the Messiah and His Mission according to Holy Scriptures both Ancient and Modern',
#   'original_pub_year': '1915',
#   'avg_rating': 4.63,
#   'ratings_count': 17179},
#  {'author': 'Hafez',
#   'original_title': 'دیوان\u200e\u200e [Dīvān]',
#   'original_pub_year': '1380',
#   'avg_rating': 4.63,
#   'ratings_count': 2773},
#  {'author': 'Eiichirō Oda',
#   'original_title': 'ONE PIECE 38',
#   'original_pub_year': '2005',
#   'avg_rating': 4.63,
#   'ratings_count': 8441},
#  {'author': 'Leigh Bardugo',
#   'original_title': 'Crooked Kingdom',
#   'original_pub_year': '2016',
#   'avg_rating': 4.62,
#   'ratings_count': 44289},
#  {'author': 'Angie Thomas',
#   'original_title': 'The Hate U Give',
#   'original_pub_year': '2017',
#   'avg_rating': 4.62,
#   'ratings_count': 32610},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Deathly Hallows',
#   'original_pub_year': '2007',
#   'avg_rating': 4.61,
#   'ratings_count': 1746574},
#  {'author': 'Bill Watterson, G.B. Trudeau',
#   'original_title': 'Calvin and Hobbes',
#   'original_pub_year': '1987',
#   'avg_rating': 4.61,
#   'ratings_count': 117788},
#  {'author': 'Anonymous',
#   'original_title': 'Holy Bible: New International Version',
#   'original_pub_year': '1909',
#   'avg_rating': 4.61,
#   'ratings_count': 40430},
#  {'author': 'John   Williams',
#   'original_title': 'Harry Potter and the Chamber of Secrets: Sheet Music for Flute with C.D',
#   'original_pub_year': '2003',
#   'avg_rating': 4.61,
#   'ratings_count': 29409},
#  {'author': 'Richelle Mead',
#   'original_title': 'Vampire Academy Collection',
#   'original_pub_year': '2009',
#   'avg_rating': 4.61,
#   'ratings_count': 30166},
#  {'author': 'Gordon B. Hinckley',
#   'original_title': 'Standing for Something: 10 Neglected Virtues That Will Heal Our Hearts and Homes',
#   'original_pub_year': '2000',
#   'avg_rating': 4.61,
#   'ratings_count': 12708},
#  {'author': 'Alisa Kwitney, Neil Gaiman',
#   'original_title': 'The Sandman: King of Dreams',
#   'original_pub_year': '2003',
#   'avg_rating': 4.61,
#   'ratings_count': 11538},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'Queen of Shadows',
#   'original_pub_year': '2015',
#   'avg_rating': 4.6,
#   'ratings_count': 99067},
#  {'author': 'Francine Rivers, Richard Ferrone',
#   'original_title': 'A Voice in the Wind',
#   'original_pub_year': '1993',
#   'avg_rating': 4.6,
#   'ratings_count': 55556},
#  {'author': 'Francine Rivers',
#   'original_title': 'An Echo in the Darkness (Mark of the Lion, #2)',
#   'original_pub_year': '1994',
#   'avg_rating': 4.6,
#   'ratings_count': 32386},
#  {'author': 'Christopher Yost, Pasqual Ferry, Orson Scott Card',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.6,
#   'ratings_count': 11585},
#  {'author': 'Cassandra Clare',
#   'original_title': 'Clockwork Princess',
#   'original_pub_year': '2013',
#   'avg_rating': 4.59,
#   'ratings_count': 162099},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Hobbit and The Lord of the Rings',
#   'original_pub_year': '1973',
#   'avg_rating': 4.59,
#   'ratings_count': 90907},
#  {'author': 'Sherrilyn Kenyon',
#   'original_title': 'Acheron (Dark-Hunter, #15) - Part 1',
#   'original_pub_year': '2008',
#   'avg_rating': 4.59,
#   'ratings_count': 44623},
#  {'author': 'Gary Russell',
#   'original_title': 'The Lord of the Rings: The Art of The Fellowship of the Ring',
#   'original_pub_year': '2002',
#   'avg_rating': 4.59,
#   'ratings_count': 24340},
#  {'author': "Neil Gaiman, Marc Hempel, Richard Case, D'Israeli, Teddy Kristiansen, Glyn Dillon, Charles Vess, Dean Ormston, Kevin Nowlan, Todd Klein, Frank McConnell",
#   'original_title': 'The Sandman: The Kindly Ones',
#   'original_pub_year': '1996',
#   'avg_rating': 4.59,
#   'ratings_count': 32544},
#  {'author': 'Jude Fisher',
#   'original_title': '',
#   'original_pub_year': '',
#   'avg_rating': 4.59,
#   'ratings_count': 17526},
#  {'author': 'BookRags',
#   'original_title': '',
#   'original_pub_year': '',
#   'avg_rating': 4.59,
#   'ratings_count': 18960},
#  {'author': 'Cassandra Clare',
#   'original_title': 'The Mortal Instrument Series: City of Bones / City of Ashes / City of Glass / City of Fallen Angels',
#   'original_pub_year': '2011',
#   'avg_rating': 4.59,
#   'ratings_count': 13996},
#  {'author': 'Cassandra Clare',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.59,
#   'ratings_count': 10426},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'Empire of Storms',
#   'original_pub_year': '2016',
#   'avg_rating': 4.58,
#   'ratings_count': 63322},
#  {'author': 'Rick Riordan',
#   'original_title': 'Percy Jackson and the Olympians Boxed Set',
#   'original_pub_year': '2008',
#   'avg_rating': 4.58,
#   'ratings_count': 32496},
#  {'author': 'Bryan Stevenson',
#   'original_title': 'Just Mercy: A Story of Justice and Redemption',
#   'original_pub_year': '2014',
#   'avg_rating': 4.58,
#   'ratings_count': 27173},
#  {'author': 'Jorge Luis Borges, Andrew Hurley',
#   'original_title': 'Cuentos completos',
#   'original_pub_year': '1998',
#   'avg_rating': 4.58,
#   'ratings_count': 16474},
#  {'author': 'Isaac Asimov, Bob E. Flick, Jim Gallant',
#   'original_title': 'The Last Question (When the World Ends)',
#   'original_pub_year': '1956',
#   'avg_rating': 4.58,
#   'ratings_count': 11762},
#  {'author': 'Sherrilyn Kenyon',
#   'original_title': 'Styxx',
#   'original_pub_year': '2013',
#   'avg_rating': 4.58,
#   'ratings_count': 14344},
#  {'author': 'Arthur Conan Doyle, William S. Baring-Gould',
#   'original_title': 'The Annotated Sherlock Holmes',
#   'original_pub_year': '1967',
#   'avg_rating': 4.58,
#   'ratings_count': 9551},
#  {'author': 'Patrick Rothfuss',
#   'original_title': "The Wise Man's Fear",
#   'original_pub_year': '2011',
#   'avg_rating': 4.57,
#   'ratings_count': 245686},
#  {'author': 'Cassandra Clare',
#   'original_title': 'The Mortal Instruments Boxed Set: City of Bones; City of Ashes; City of Glass',
#   'original_pub_year': '2009',
#   'avg_rating': 4.57,
#   'ratings_count': 55518},
#  {'author': 'Brian K. Vaughan, Fiona Staples',
#   'original_title': 'Saga, Volume Two',
#   'original_pub_year': '2013',
#   'avg_rating': 4.57,
#   'ratings_count': 56122},
#  {'author': 'Richelle Mead',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.57,
#   'ratings_count': 33015},
#  {'author': 'Masashi Kishimoto',
#   'original_title': 'NARUTO -ナルト- 巻ノ四十三 ',
#   'original_pub_year': '2008',
#   'avg_rating': 4.57,
#   'ratings_count': 26364},
#  {'author': 'Rick Riordan, Tk',
#   'original_title': 'Percy Jackson and the Olympians',
#   'original_pub_year': '2009',
#   'avg_rating': 4.57,
#   'ratings_count': 19555},
#  {'author': 'Safiy al-Rahman al-Mubarakfuri',
#   'original_title': ' الرحيق المختوم: بحث في السيرة النبوية على صاحبها أفضل الصلاة والسلام ',
#   'original_pub_year': '1979',
#   'avg_rating': 4.57,
#   'ratings_count': 10558},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Binds',
#   'original_pub_year': '2016',
#   'avg_rating': 4.57,
#   'ratings_count': 10983},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Storm of Swords: Part 2 Blood and Gold',
#   'original_pub_year': '2000',
#   'avg_rating': 4.56,
#   'ratings_count': 54977},
#  {'author': 'Brian K. Vaughan, Fiona Staples',
#   'original_title': 'Saga, Volume Three',
#   'original_pub_year': '2014',
#   'avg_rating': 4.56,
#   'ratings_count': 47549},
#  {'author': 'Bob McCabe',
#   'original_title': 'Harry Potter Page to Screen: The Complete Filmmaking Journey',
#   'original_pub_year': '2011',
#   'avg_rating': 4.56,
#   'ratings_count': 27361},
#  {'author': 'K. Bromberg',
#   'original_title': 'Crashed',
#   'original_pub_year': '2014',
#   'avg_rating': 4.56,
#   'ratings_count': 32520},
#  {'author': 'J.K. Rowling',
#   'original_title': '',
#   'original_pub_year': '2003',
#   'avg_rating': 4.56,
#   'ratings_count': 16249},
#  {'author': 'Veronica Roth',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.56,
#   'ratings_count': 12490},
#  {'author': 'Amie Kaufman, Jay Kristoff, Marie Lu',
#   'original_title': 'Gemina',
#   'original_pub_year': '2016',
#   'avg_rating': 4.56,
#   'ratings_count': 10960},
#  {'author': 'Patrick Rothfuss',
#   'original_title': 'The Name of the Wind',
#   'original_pub_year': '2007',
#   'avg_rating': 4.55,
#   'ratings_count': 400101},
#  {'author': 'Jim Butcher',
#   'original_title': 'Skin Game',
#   'original_pub_year': '2014',
#   'avg_rating': 4.55,
#   'ratings_count': 41512},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'Mistborn Trilogy Boxed Set',
#   'original_pub_year': '2009',
#   'avg_rating': 4.55,
#   'ratings_count': 22917},
#  {'author': 'Neil Gaiman, Jill Thompson, Vince Locke, Peter Straub',
#   'original_title': 'The Sandman: Brief Lives',
#   'original_pub_year': '1994',
#   'avg_rating': 4.55,
#   'ratings_count': 36487},
#  {'author': 'Andrew Williamson, Andrew Williamson',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.55,
#   'ratings_count': 22847},
#  {'author': 'Jane Austen',
#   'original_title': '',
#   'original_pub_year': '1813',
#   'avg_rating': 4.55,
#   'ratings_count': 18828},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.55,
#   'ratings_count': 24846},
#  {'author': 'Stephen King',
#   'original_title': 'The Green Mile, Part 6: Coffey on the Mile',
#   'original_pub_year': '1996',
#   'avg_rating': 4.55,
#   'ratings_count': 11936},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Half-Blood Prince',
#   'original_pub_year': '2005',
#   'avg_rating': 4.54,
#   'ratings_count': 1678823},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Storm of Swords',
#   'original_pub_year': '2000',
#   'avg_rating': 4.54,
#   'ratings_count': 469022},
#  {'author': 'Kristin Hannah',
#   'original_title': 'The Nightingale',
#   'original_pub_year': '2015',
#   'avg_rating': 4.54,
#   'ratings_count': 253606},
#  {'author': 'Rick Riordan',
#   'original_title': 'The House of Hades',
#   'original_pub_year': '2013',
#   'avg_rating': 4.54,
#   'ratings_count': 159774},
#  {'author': 'Jim Butcher',
#   'original_title': 'Changes',
#   'original_pub_year': '2010',
#   'avg_rating': 4.54,
#   'ratings_count': 66402},
#  {'author': 'Sarah  Young',
#   'original_title': '',
#   'original_pub_year': '2004',
#   'avg_rating': 4.54,
#   'ratings_count': 35219},
#  {'author': 'Neil Gaiman, Matt Wagner, George Pratt, Dick Giordano, Kelley Jones, P. Craig Russell, Mike Dringenberg, Malcolm Jones III, Todd Klein, Harlan Ellison',
#   'original_title': 'The Sandman: Season of Mists',
#   'original_pub_year': '1990',
#   'avg_rating': 4.54,
#   'ratings_count': 44811},
#  {'author': 'Founding Fathers',
#   'original_title': 'The Constitution of the United States of America',
#   'original_pub_year': '1787',
#   'avg_rating': 4.54,
#   'ratings_count': 16863},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'A Court of Wings and Ruin',
#   'original_pub_year': '2017',
#   'avg_rating': 4.54,
#   'ratings_count': 55037},
#  {'author': 'Chris Colfer, Brandon Dorman',
#   'original_title': 'A Grimm Warning',
#   'original_pub_year': '2014',
#   'avg_rating': 4.54,
#   'ratings_count': 13695},
#  {'author': 'Bisco Hatori',
#   'original_title': '桜蘭高校ホスト部 15',
#   'original_pub_year': '2009',
#   'avg_rating': 4.54,
#   'ratings_count': 10743},
#  {'author': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'original_title': 'Harry Potter and the Prisoner of Azkaban',
#   'original_pub_year': '1999',
#   'avg_rating': 4.53,
#   'ratings_count': 1832823},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Goblet of Fire',
#   'original_pub_year': '2000',
#   'avg_rating': 4.53,
#   'ratings_count': 1753043},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'Heir of Fire',
#   'original_pub_year': '2014',
#   'avg_rating': 4.53,
#   'ratings_count': 123843},
#  {'author': 'Art Spiegelman',
#   'original_title': 'The Complete Maus',
#   'original_pub_year': '1986',
#   'avg_rating': 4.53,
#   'ratings_count': 76785},
#  {'author': 'Neil Gaiman, Michael Zulli, Jon J. Muth, Charles Vess, Mikal Gilmore',
#   'original_title': 'The Sandman: The Wake',
#   'original_pub_year': '1996',
#   'avg_rating': 4.53,
#   'ratings_count': 32360},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Clash of Kings',
#   'original_pub_year': '1996',
#   'avg_rating': 4.53,
#   'ratings_count': 22259},
#  {'author': 'Chris   Smith, Christopher Lee, Richard Taylor',
#   'original_title': 'The Lord of the Rings: Weapons and Warfare',
#   'original_pub_year': '',
#   'avg_rating': 4.53,
#   'ratings_count': 18788},
#  {'author': 'Yana Toboso',
#   'original_title': '黒執事 III [Kuroshitsuji III]',
#   'original_pub_year': '2007',
#   'avg_rating': 4.53,
#   'ratings_count': 16682},
#  {'author': 'Robin Hobb',
#   'original_title': "Fool's Quest",
#   'original_pub_year': '2015',
#   'avg_rating': 4.53,
#   'ratings_count': 12374},
#  {'author': 'David Foster Wallace',
#   'original_title': 'This is Water',
#   'original_pub_year': '2009',
#   'avg_rating': 4.53,
#   'ratings_count': 13312},
#  {'author': 'Robert Kirkman, Charlie Adlard',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.53,
#   'ratings_count': 13478},
#  {'author': 'Eric Blehm',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.53,
#   'ratings_count': 7793},
#  {'author': 'Randy Alcorn, Alex Kendrick, Stephen Kendrick',
#   'original_title': 'Courageous',
#   'original_pub_year': '2011',
#   'avg_rating': 4.53,
#   'ratings_count': 9409},
#  {'author': 'Hiro Fujiwara',
#   'original_title': '会長はメイド様! 2',
#   'original_pub_year': '2007',
#   'avg_rating': 4.53,
#   'ratings_count': 9843},
#  {'author': 'Roberto Aguirre-Sacasa, Mike Perkins, Laura       Martin, Stephen King',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.52,
#   'ratings_count': 40626},
#  {'author': 'Erin Hunter',
#   'original_title': '',
#   'original_pub_year': '2005',
#   'avg_rating': 4.52,
#   'ratings_count': 26949},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Breaks',
#   'original_pub_year': '2014',
#   'avg_rating': 4.52,
#   'ratings_count': 22583},
#  {'author': 'Patricia Polacco',
#   'original_title': 'Thank You, Mr. Falker',
#   'original_pub_year': '1998',
#   'avg_rating': 4.52,
#   'ratings_count': 13049},
#  {'author': 'Angela Elwell Hunt, Tim Jonke',
#   'original_title': 'The Tale of Three Trees: A Traditional Folktale',
#   'original_pub_year': '1989',
#   'avg_rating': 4.52,
#   'ratings_count': 13226},
#  {'author': 'Stephen King',
#   'original_title': 'The Green Mile, Part 4: The Bad Death of Eduard Delacroix',
#   'original_pub_year': '1996',
#   'avg_rating': 4.52,
#   'ratings_count': 12958},
#  {'author': 'Stephen King',
#   'original_title': 'The Shawshank Redemption',
#   'original_pub_year': '1982',
#   'avg_rating': 4.52,
#   'ratings_count': 11499},
#  {'author': 'Stephen King',
#   'original_title': "Three Complete Novels: Carrie/Salem's Lot/The Shining",
#   'original_pub_year': '1983',
#   'avg_rating': 4.52,
#   'ratings_count': 11063},
#  {'author': 'Michael Dante DiMartino, Bryan Konietzko',
#   'original_title': 'Avatar: Last Airbender v. 1 (Avatar (Graphic Novels))',
#   'original_pub_year': '2006',
#   'avg_rating': 4.52,
#   'ratings_count': 8261},
#  {'author': 'Hajime Isayama, Hikaru Suruga, Gan Sunaaku',
#   'original_title': '進撃の巨人 悔いなき選択 1',
#   'original_pub_year': '2014',
#   'avg_rating': 4.52,
#   'ratings_count': 9032},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Return of the King',
#   'original_pub_year': '1955',
#   'avg_rating': 4.51,
#   'ratings_count': 463959},
#  {'author': 'Kate Egan',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.51,
#   'ratings_count': 119915},
#  {'author': 'Jim Butcher',
#   'original_title': 'Cold Days',
#   'original_pub_year': '2012',
#   'avg_rating': 4.51,
#   'ratings_count': 57779},
#  {'author': 'Douglas Adams',
#   'original_title': "The Hitchhiker's Guide to the Galaxy: The Trilogy of Four (Hitchhiker's Guide, #1-4)",
#   'original_pub_year': '1986',
#   'avg_rating': 4.51,
#   'ratings_count': 27855},
#  {'author': 'K. Bromberg',
#   'original_title': 'Fueled',
#   'original_pub_year': '2013',
#   'avg_rating': 4.51,
#   'ratings_count': 37667},
#  {'author': 'J.R. Ward',
#   'original_title': '',
#   'original_pub_year': '2008',
#   'avg_rating': 4.51,
#   'ratings_count': 32178},
#  {'author': 'Rick Riordan, John Rocco',
#   'original_title': "Percy Jackson's Greek Gods",
#   'original_pub_year': '2014',
#   'avg_rating': 4.51,
#   'ratings_count': 24718},
#  {'author': 'Stephen E. Robinson',
#   'original_title': 'Believing Christ: The Parable of the Bicycle and Other Good News',
#   'original_pub_year': '1992',
#   'avg_rating': 4.51,
#   'ratings_count': 12951},
#  {'author': 'C.S. Pacat',
#   'original_title': "Prince's Gambit",
#   'original_pub_year': '2015',
#   'avg_rating': 4.51,
#   'ratings_count': 15899},
#  {'author': 'Stephen King',
#   'original_title': 'The Green Mile, Part 5: Night Journey',
#   'original_pub_year': '1996',
#   'avg_rating': 4.51,
#   'ratings_count': 11442},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Last Olympian',
#   'original_pub_year': '2009',
#   'avg_rating': 4.5,
#   'ratings_count': 397500},
#  {'author': 'Arthur Conan Doyle',
#   'original_title': 'The Complete Sherlock Holmes',
#   'original_pub_year': '1894',
#   'avg_rating': 4.5,
#   'ratings_count': 109754},
#  {'author': 'Robert Jordan, Brandon Sanderson',
#   'original_title': 'A Memory of Light',
#   'original_pub_year': '2012',
#   'avg_rating': 4.5,
#   'ratings_count': 68410},
#  {'author': 'Diana Gabaldon',
#   'original_title': "Written in My Own Heart's Blood",
#   'original_pub_year': '2014',
#   'avg_rating': 4.5,
#   'ratings_count': 46663},
#  {'author': 'Pierce Brown',
#   'original_title': 'Morning Star',
#   'original_pub_year': '2016',
#   'avg_rating': 4.5,
#   'ratings_count': 47736},
#  {'author': 'Masashi Kishimoto, Frances Wall',
#   'original_title': 'NARUTO -ナルト- 巻ノ十一 ',
#   'original_pub_year': '2002',
#   'avg_rating': 4.5,
#   'ratings_count': 15214},
#  {'author': 'Joe Hill, Gabriel Rodríguez',
#   'original_title': 'Clockworks',
#   'original_pub_year': '2013',
#   'avg_rating': 4.5,
#   'ratings_count': 16441},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.5,
#   'ratings_count': 26940},
#  {'author': 'Fernando Pessoa, Richard Zenith',
#   'original_title': 'Livro do Desassossego',
#   'original_pub_year': '1913',
#   'avg_rating': 4.5,
#   'ratings_count': 9115},
#  {'author': 'C.S. Pacat',
#   'original_title': 'Kings Rising',
#   'original_pub_year': '2016',
#   'avg_rating': 4.5,
#   'ratings_count': 14210},
#  {'author': 'Joe Hill, Gabriel Rodríguez',
#   'original_title': 'Locke & Key, Vol. 6: Alpha & Omega',
#   'original_pub_year': '2014',
#   'avg_rating': 4.5,
#   'ratings_count': 14363},
#  {'author': 'Brandon Stanton',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.5,
#   'ratings_count': 12614},
#  {'author': 'Stephen King',
#   'original_title': "The Green Mile, Part 3: Coffey's Hands",
#   'original_pub_year': '1996',
#   'avg_rating': 4.5,
#   'ratings_count': 12232},
#  {'author': 'Brandon Stanton',
#   'original_title': 'Humans of New York: Stories',
#   'original_pub_year': '2015',
#   'avg_rating': 4.5,
#   'ratings_count': 12527},
#  {'author': 'Quinn Loftis',
#   'original_title': 'Out of the Dark ',
#   'original_pub_year': '2012',
#   'avg_rating': 4.5,
#   'ratings_count': 11994},
#  {'author': 'Suzanne Collins',
#   'original_title': 'The Hunger Games Box Set',
#   'original_pub_year': '2010',
#   'avg_rating': 4.49,
#   'ratings_count': 129665},
#  {'author': 'Sarah J. Maas',
#   'original_title': 'Crown of Midnight',
#   'original_pub_year': '2013',
#   'avg_rating': 4.49,
#   'ratings_count': 160485},
#  {'author': 'Hiromu Arakawa, Akira Watanabe',
#   'original_title': '鋼の錬金術師 1',
#   'original_pub_year': '2002',
#   'avg_rating': 4.49,
#   'ratings_count': 93990},
#  {'author': 'Marissa Meyer',
#   'original_title': 'Winter',
#   'original_pub_year': '2015',
#   'avg_rating': 4.49,
#   'ratings_count': 100464},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Storm of Swords: Part 1 Steel and Snow',
#   'original_pub_year': '2000',
#   'avg_rating': 4.49,
#   'ratings_count': 42072},
#  {'author': 'William Shakespeare',
#   'original_title': 'The Complete Works',
#   'original_pub_year': '1623',
#   'avg_rating': 4.49,
#   'ratings_count': 39503},
#  {'author': 'A.A. Milne, Ernest H. Shepard',
#   'original_title': '',
#   'original_pub_year': '1961',
#   'avg_rating': 4.49,
#   'ratings_count': 37312},
#  {'author': 'Trevor Noah',
#   'original_title': '',
#   'original_pub_year': '2016',
#   'avg_rating': 4.49,
#   'ratings_count': 42573},
#  {'author': 'Michelle Alexander',
#   'original_title': 'The New Jim Crow: Mass Incarceration in the Age of Colorblindness',
#   'original_pub_year': '2010',
#   'avg_rating': 4.49,
#   'ratings_count': 23205},
#  {'author': 'Don Ferguson',
#   'original_title': "Disney's the Lion King (Disney Classic Series)",
#   'original_pub_year': '1994',
#   'avg_rating': 4.49,
#   'ratings_count': 19553},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Rises',
#   'original_pub_year': '2013',
#   'avg_rating': 4.49,
#   'ratings_count': 29556},
#  {'author': 'Sabahattin Ali',
#   'original_title': 'Kürk Mantolu Madonna',
#   'original_pub_year': '1943',
#   'avg_rating': 4.49,
#   'ratings_count': 19806},
#  {'author': 'Stephen King',
#   'original_title': 'The Green Mile, Part 1: The Two Dead Girls',
#   'original_pub_year': '1996',
#   'avg_rating': 4.49,
#   'ratings_count': 21917},
#  {'author': 'Jennifer L. Armentrout',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.49,
#   'ratings_count': 24150},
#  {'author': 'Brian K. Vaughan, Fiona Staples',
#   'original_title': 'Saga, Volume Six',
#   'original_pub_year': '2016',
#   'avg_rating': 4.49,
#   'ratings_count': 18433},
#  {'author': 'Chris Colfer, Brandon Dorman',
#   'original_title': 'The Enchantress Returns',
#   'original_pub_year': '2013',
#   'avg_rating': 4.49,
#   'ratings_count': 17845},
#  {'author': 'Darynda Jones',
#   'original_title': 'Fifth Grave Past the Light',
#   'original_pub_year': '2013',
#   'avg_rating': 4.49,
#   'ratings_count': 21286},
#  {'author': 'Kristen Ashley',
#   'original_title': 'At Peace',
#   'original_pub_year': '2011',
#   'avg_rating': 4.49,
#   'ratings_count': 23308},
#  {'author': 'Karen Kingsbury, Gary Smalley',
#   'original_title': 'Reunion',
#   'original_pub_year': '2004',
#   'avg_rating': 4.49,
#   'ratings_count': 11105},
#  {'author': 'Malvina G. Vogel, Arthur Conan Doyle',
#   'original_title': '',
#   'original_pub_year': '1977',
#   'avg_rating': 4.49,
#   'ratings_count': 9805},
#  {'author': 'Chuck Dixon, J.R.R. Tolkien, David Wenzel, Sean Deming',
#   'original_title': 'The Hobbit',
#   'original_pub_year': '1989',
#   'avg_rating': 4.48,
#   'ratings_count': 155338},
#  {'author': 'Francine Rivers',
#   'original_title': '',
#   'original_pub_year': '1991',
#   'avg_rating': 4.48,
#   'ratings_count': 157506},
#  {'author': 'Cassandra Clare',
#   'original_title': 'City of Heavenly Fire',
#   'original_pub_year': '2014',
#   'avg_rating': 4.48,
#   'ratings_count': 177796},
#  {'author': 'Brian Sibley',
#   'original_title': 'Harry Potter: Film Wizardry',
#   'original_pub_year': '2010',
#   'avg_rating': 4.48,
#   'ratings_count': 45081},
#  {'author': 'Sarah J. Maas',
#   'original_title': "The Assassin's Blade",
#   'original_pub_year': '2014',
#   'avg_rating': 4.48,
#   'ratings_count': 53227},
#  {'author': 'Daniel Abraham, George R.R. Martin, Tommy Patterson',
#   'original_title': 'A Game of Thrones - The Graphic Novel Volume 1',
#   'original_pub_year': '2011',
#   'avg_rating': 4.48,
#   'ratings_count': 25533},
#  {'author': 'Neil Gaiman, Mike Allred, Gary Amaro, Mark Buckingham, David Giordano, Tony Harris, Steve Leialoha, Vince Locke, Shea Anton Pensa, Alec Stevens, Bryan Talbot, John Watkiss, Todd Klein, Michael Zulli, Stephen King',
#   'original_title': "The Sandman: Worlds' End",
#   'original_pub_year': '1995',
#   'avg_rating': 4.48,
#   'ratings_count': 32362},
#  {'author': 'Cinda Williams Chima',
#   'original_title': 'The Crimson Crown',
#   'original_pub_year': '2012',
#   'avg_rating': 4.48,
#   'ratings_count': 27279},
#  {'author': 'Erich Maria Remarque',
#   'original_title': 'Drei Kameraden',
#   'original_pub_year': '1936',
#   'avg_rating': 4.48,
#   'ratings_count': 14321},
#  {'author': 'Kate Egan',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.48,
#   'ratings_count': 15060},
#  {'author': 'Yana Toboso, Tomo Kimura',
#   'original_title': '黒執事 II [Kuroshitsuji II]',
#   'original_pub_year': '2007',
#   'avg_rating': 4.48,
#   'ratings_count': 15194},
#  {'author': 'Harold McGee',
#   'original_title': 'On Food and Cooking: The Science and Lore of the Kitchen',
#   'original_pub_year': '1984',
#   'avg_rating': 4.48,
#   'ratings_count': 10631},
#  {'author': 'Matthew Desmond',
#   'original_title': 'Evicted: Poverty and Profit in the American City',
#   'original_pub_year': '2016',
#   'avg_rating': 4.48,
#   'ratings_count': 15165},
#  {'author': 'Quinn Loftis',
#   'original_title': 'Just One Drop',
#   'original_pub_year': '2012',
#   'avg_rating': 4.48,
#   'ratings_count': 15606},
#  {'author': 'Charles M. Schulz',
#   'original_title': 'A Charlie Brown Christmas ',
#   'original_pub_year': '1965',
#   'avg_rating': 4.48,
#   'ratings_count': 11639},
#  {'author': 'Assata Shakur, Angela Y. Davis, Lennox S. Hinds',
#   'original_title': 'Assata: An Autobiography',
#   'original_pub_year': '1987',
#   'avg_rating': 4.48,
#   'ratings_count': 10518},
#  {'author': 'Edgar Allan Poe',
#   'original_title': 'The Complete Tales and Poems of Edgar Allan Poe',
#   'original_pub_year': '1849',
#   'avg_rating': 4.48,
#   'ratings_count': 3427},
#  {'author': 'Neal Shusterman',
#   'original_title': 'UnDivided',
#   'original_pub_year': '2014',
#   'avg_rating': 4.48,
#   'ratings_count': 11403},
#  {'author': 'Derek Landy',
#   'original_title': 'Mortal Coil',
#   'original_pub_year': '2010',
#   'avg_rating': 4.48,
#   'ratings_count': 10972},
#  {'author': 'Justine Korman Fontes',
#   'original_title': '',
#   'original_pub_year': '1994',
#   'avg_rating': 4.48,
#   'ratings_count': 9247},
#  {'author': 'Perry Moore, Andrew Adamson, C.S. Lewis',
#   'original_title': 'The Chronicles of Narnia - The Lion, the Witch, and the Wardrobe Official Illustrated Movie Companion',
#   'original_pub_year': '2005',
#   'avg_rating': 4.48,
#   'ratings_count': 7328},
#  {'author': 'Kazue Kato',
#   'original_title': '青の祓魔師 2',
#   'original_pub_year': '2009',
#   'avg_rating': 4.48,
#   'ratings_count': 8972},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Lord of the Rings',
#   'original_pub_year': '1955',
#   'avg_rating': 4.47,
#   'ratings_count': 389054},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Mark of Athena',
#   'original_pub_year': '2012',
#   'avg_rating': 4.47,
#   'ratings_count': 277491},
#  {'author': 'Larry McMurtry',
#   'original_title': 'Lonesome Dove',
#   'original_pub_year': '1985',
#   'avg_rating': 4.47,
#   'ratings_count': 111498},
#  {'author': 'Terry Pratchett',
#   'original_title': 'Night Watch',
#   'original_pub_year': '2002',
#   'avg_rating': 4.47,
#   'ratings_count': 71271},
#  {'author': 'Anthony  Ryan',
#   'original_title': 'Blood Song',
#   'original_pub_year': '2011',
#   'avg_rating': 4.47,
#   'ratings_count': 44014},
#  {'author': 'Cassandra Clare',
#   'original_title': 'Lady Midnight',
#   'original_pub_year': '2016',
#   'avg_rating': 4.47,
#   'ratings_count': 84711},
#  {'author': 'Eric Wilson',
#   'original_title': 'Fireproof',
#   'original_pub_year': '2008',
#   'avg_rating': 4.47,
#   'ratings_count': 37258},
#  {'author': 'Chimamanda Ngozi Adichie',
#   'original_title': 'We Should All Be Feminists',
#   'original_pub_year': '2014',
#   'avg_rating': 4.47,
#   'ratings_count': 46048},
#  {'author': 'Jorge Luis Borges, Anthony Kerrigan, Anthony Bonner',
#   'original_title': 'Ficciones',
#   'original_pub_year': '1944',
#   'avg_rating': 4.47,
#   'ratings_count': 28657},
#  {'author': 'Brian K. Vaughan, Fiona Staples',
#   'original_title': 'Saga, Volume Four',
#   'original_pub_year': '2014',
#   'avg_rating': 4.47,
#   'ratings_count': 38069},
#  {'author': 'Sister Souljah',
#   'original_title': 'The Coldest Winter Ever',
#   'original_pub_year': '1999',
#   'avg_rating': 4.47,
#   'ratings_count': 23737},
#  {'author': 'Kresley Cole',
#   'original_title': 'Demon From the Dark ',
#   'original_pub_year': '2010',
#   'avg_rating': 4.47,
#   'ratings_count': 34257},
#  {'author': 'Robert Kirkman',
#   'original_title': 'The Walking Dead, Vol. 8: Made To Suffer',
#   'original_pub_year': '2008',
#   'avg_rating': 4.47,
#   'ratings_count': 22017},
#  {'author': 'Julia Donaldson, Axel Scheffler',
#   'original_title': 'The Gruffalo',
#   'original_pub_year': '1999',
#   'avg_rating': 4.47,
#   'ratings_count': 19609},
#  {'author': 'Corrie ten Boom',
#   'original_title': 'Tramp for the Lord',
#   'original_pub_year': '1974',
#   'avg_rating': 4.47,
#   'ratings_count': 16680},
#  {'author': 'Lin-Manuel Miranda, Jeremy McCarter',
#   'original_title': 'Hamilton: The Revolution',
#   'original_pub_year': '2016',
#   'avg_rating': 4.47,
#   'ratings_count': 24800},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Shifts',
#   'original_pub_year': '2015',
#   'avg_rating': 4.47,
#   'ratings_count': 16363},
#  {'author': 'Kelley Armstrong',
#   'original_title': 'Darkest Powers Trilogy (Darkest Powers, #1-3)',
#   'original_pub_year': '2009',
#   'avg_rating': 4.47,
#   'ratings_count': 14473},
#  {'author': 'Andrew Stanton, Walt Disney Company',
#   'original_title': 'Finding Nemo',
#   'original_pub_year': '1996',
#   'avg_rating': 4.47,
#   'ratings_count': 12160},
#  {'author': 'Nalini Singh',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.47,
#   'ratings_count': 18759},
#  {'author': 'Stephen King',
#   'original_title': 'The Green Mile, Part 2: The Mouse on the Mile',
#   'original_pub_year': '1996',
#   'avg_rating': 4.47,
#   'ratings_count': 11985},
#  {'author': 'Tijan',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.47,
#   'ratings_count': 15319},
#  {'author': 'Anton Chekhov, Richard Pevear, Larissa Volokhonsky',
#   'original_title': '',
#   'original_pub_year': '1896',
#   'avg_rating': 4.47,
#   'ratings_count': 9424},
#  {'author': 'Atsushi Ohkubo',
#   'original_title': ' ソウルイーター 2',
#   'original_pub_year': '2004',
#   'avg_rating': 4.47,
#   'ratings_count': 9443},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Order of the Phoenix',
#   'original_pub_year': '2003',
#   'avg_rating': 4.46,
#   'ratings_count': 1735368},
#  {'author': 'Cassandra Clare',
#   'original_title': 'Clockwork Prince',
#   'original_pub_year': '2011',
#   'avg_rating': 4.46,
#   'ratings_count': 307994},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'The Hero of Ages',
#   'original_pub_year': '2008',
#   'avg_rating': 4.46,
#   'ratings_count': 143622},
#  {'author': 'Marissa Meyer',
#   'original_title': 'Cress',
#   'original_pub_year': '2014',
#   'avg_rating': 4.46,
#   'ratings_count': 162069},
#  {'author': 'Arthur Conan Doyle, Kyle Freeman',
#   'original_title': 'Sherlock Holmes: The Complete Novels and Stories, Vol 2',
#   'original_pub_year': '1914',
#   'avg_rating': 4.46,
#   'ratings_count': 66857},
#  {'author': 'Pierce Brown',
#   'original_title': 'Golden Son',
#   'original_pub_year': '2015',
#   'avg_rating': 4.46,
#   'ratings_count': 57614},
#  {'author': 'Leigh Bardugo',
#   'original_title': 'Six of Crows',
#   'original_pub_year': '2015',
#   'avg_rating': 4.46,
#   'ratings_count': 90202},
#  {'author': 'Karen Marie Moning',
#   'original_title': 'Shadowfever',
#   'original_pub_year': '2011',
#   'avg_rating': 4.46,
#   'ratings_count': 73030},
#  {'author': 'Stieg Larsson, Reg Keeland',
#   'original_title': 'Män som hatar kvinnor, Flickan som lekte med elden, Luftslottet som sprängdes',
#   'original_pub_year': '2005',
#   'avg_rating': 4.46,
#   'ratings_count': 29944},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Bleeds',
#   'original_pub_year': '2010',
#   'avg_rating': 4.46,
#   'ratings_count': 50637},
#  {'author': 'Brent Weeks',
#   'original_title': 'The Broken Eye',
#   'original_pub_year': '2014',
#   'avg_rating': 4.46,
#   'ratings_count': 27754},
#  {'author': 'Michael J. Sullivan',
#   'original_title': 'Heir of Novron',
#   'original_pub_year': '2012',
#   'avg_rating': 4.46,
#   'ratings_count': 25185},
#  {'author': 'Justine Korman Fontes, Don Williams, Walt Disney Company',
#   'original_title': 'The Lion King (Little Golden Book)',
#   'original_pub_year': '1994',
#   'avg_rating': 4.46,
#   'ratings_count': 23098},
#  {'author': 'Jorge Luis Borges, Donald A. Yates, James E. Irby, André Maurois',
#   'original_title': 'Labyrinths',
#   'original_pub_year': '1962',
#   'avg_rating': 4.46,
#   'ratings_count': 20237},
#  {'author': 'Louise Penny',
#   'original_title': 'A Great Reckoning',
#   'original_pub_year': '2016',
#   'avg_rating': 4.46,
#   'ratings_count': 13563},
#  {'author': 'Phil Knight',
#   'original_title': 'Shoe Dog: A Memoir by the Creator of Nike',
#   'original_pub_year': '2016',
#   'avg_rating': 4.46,
#   'ratings_count': 22373},
#  {'author': 'Lambert M. Surhone',
#   'original_title': '',
#   'original_pub_year': '',
#   'avg_rating': 4.46,
#   'ratings_count': 11643},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.46,
#   'ratings_count': 26554},
#  {'author': 'Bisco Hatori',
#   'original_title': '桜蘭高校ホスト部 2',
#   'original_pub_year': '2003',
#   'avg_rating': 4.46,
#   'ratings_count': 14350},
#  {'author': 'Beatrix Potter',
#   'original_title': 'The Complete Adventures of Peter Rabbit',
#   'original_pub_year': '1982',
#   'avg_rating': 4.46,
#   'ratings_count': 13271},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.46,
#   'ratings_count': 19965},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.46,
#   'ratings_count': 19783},
#  {'author': 'Natsuki Takaya, Alethea Nibley, Athena Nibley',
#   'original_title': 'フルーツバスケット 14',
#   'original_pub_year': '2004',
#   'avg_rating': 4.46,
#   'ratings_count': 13072},
#  {'author': 'Jenny Han',
#   'original_title': 'The summer I turned pretty',
#   'original_pub_year': '2009',
#   'avg_rating': 4.46,
#   'ratings_count': 9308},
#  {'author': 'Ellen Levine, Kadir Nelson',
#   'original_title': '',
#   'original_pub_year': '2007',
#   'avg_rating': 4.46,
#   'ratings_count': 11204},
#  {'author': 'R.K. Lilley',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.46,
#   'ratings_count': 18490},
#  {'author': 'Kathryn Stockett',
#   'original_title': 'The Help',
#   'original_pub_year': '2009',
#   'avg_rating': 4.45,
#   'ratings_count': 1531753},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Game of Thrones',
#   'original_pub_year': '1996',
#   'avg_rating': 4.45,
#   'ratings_count': 1319204},
#  {'author': 'J.R. Ward',
#   'original_title': 'Lover Awakened (Black Dagger Brotherhood, #3)',
#   'original_pub_year': '2006',
#   'avg_rating': 4.45,
#   'ratings_count': 134249},
#  {'author': 'Jon Stone, Michael J. Smollin',
#   'original_title': 'The Monster at the End of This Book',
#   'original_pub_year': '1971',
#   'avg_rating': 4.45,
#   'ratings_count': 102184},
#  {'author': 'Jim Butcher',
#   'original_title': 'Turn Coat',
#   'original_pub_year': '2009',
#   'avg_rating': 4.45,
#   'ratings_count': 64089},
#  {'author': 'Brent Weeks',
#   'original_title': 'The Blinding Knife',
#   'original_pub_year': '2012',
#   'avg_rating': 4.45,
#   'ratings_count': 42445},
#  {'author': 'Max Lucado',
#   'original_title': 'You Are Special: A Story for Everyone',
#   'original_pub_year': '1997',
#   'avg_rating': 4.45,
#   'ratings_count': 41052},
#  {'author': 'Mia Sheridan',
#   'original_title': "Archer's Voice",
#   'original_pub_year': '2014',
#   'avg_rating': 4.45,
#   'ratings_count': 53131},
#  {'author': 'Michelle Rowen, Richelle Mead',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.45,
#   'ratings_count': 32818},
#  {'author': 'Neil Gaiman, Bryan Talbot, Stan Woch, P. Craig Russell, Shawn McManus, John Watkiss, Jill Thompson, Duncan Eagleson, Kent Williams, Todd Klein',
#   'original_title': 'The Sandman: Fables and Reflections',
#   'original_pub_year': '1990',
#   'avg_rating': 4.45,
#   'ratings_count': 35930},
#  {'author': 'Brandon Sanderson',
#   'original_title': 'The Bands of Mourning',
#   'original_pub_year': '2016',
#   'avg_rating': 4.45,
#   'ratings_count': 28866},
#  {'author': 'Kim Harrison',
#   'original_title': 'Pale Demon',
#   'original_pub_year': '2011',
#   'avg_rating': 4.45,
#   'ratings_count': 35141},
#  {'author': 'Gary Larson',
#   'original_title': 'The Far Side Gallery 3',
#   'original_pub_year': '1984',
#   'avg_rating': 4.45,
#   'ratings_count': 24199},
#  {'author': 'James     Baldwin, Kıvanç Güney',
#   'original_title': 'The Fire Next Time',
#   'original_pub_year': '1963',
#   'avg_rating': 4.45,
#   'ratings_count': 19816},
#  {'author': 'Arthur Conan Doyle',
#   'original_title': 'Sherlock Holmes: The Complete Novels and Stories, Volume I',
#   'original_pub_year': '1927',
#   'avg_rating': 4.45,
#   'ratings_count': 17950},
#  {'author': 'Kim Harrison',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.45,
#   'ratings_count': 22312},
#  {'author': 'Oscar Wilde, Merlin Holland',
#   'original_title': 'Collected Works',
#   'original_pub_year': '1908',
#   'avg_rating': 4.45,
#   'ratings_count': 10835},
#  {'author': 'Barbara Cooney',
#   'original_title': 'Miss Rumphius',
#   'original_pub_year': '1981',
#   'avg_rating': 4.45,
#   'ratings_count': 20403},
#  {'author': 'Jeff Kinney',
#   'original_title': '',
#   'original_pub_year': '2009',
#   'avg_rating': 4.45,
#   'ratings_count': 10752},
#  {'author': 'J.R. Ward',
#   'original_title': 'The Beast',
#   'original_pub_year': '2016',
#   'avg_rating': 4.45,
#   'ratings_count': 13243},
#  {'author': 'Beth Moore',
#   'original_title': "Praying God's Word: Breaking Free From Spiritual Strongholds",
#   'original_pub_year': '2000',
#   'avg_rating': 4.45,
#   'ratings_count': 9530},
#  {'author': 'Karen Kingsbury, Gary Smalley',
#   'original_title': 'Rejoice',
#   'original_pub_year': '2004',
#   'avg_rating': 4.45,
#   'ratings_count': 11013},
#  {'author': 'Derek Landy',
#   'original_title': 'Dark Days',
#   'original_pub_year': '2010',
#   'avg_rating': 4.45,
#   'ratings_count': 12047},
#  {'author': 'Stephen Schwartz, Gregory Maguire',
#   'original_title': 'Wicked - Piano/Vocal Arrangement',
#   'original_pub_year': '2004',
#   'avg_rating': 4.45,
#   'ratings_count': 10729},
#  {'author': 'David Baggett, Shawn E. Klein',
#   'original_title': 'Harry Potter and Philosophy: If Aristotle Ran Hogwarts',
#   'original_pub_year': '2004',
#   'avg_rating': 4.45,
#   'ratings_count': 9264},
#  {'author': 'Natsuki Takaya, Alethea Nibley, Athena Nibley',
#   'original_title': 'フルーツバスケット 15',
#   'original_pub_year': '2004',
#   'avg_rating': 4.45,
#   'ratings_count': 12888},
#  {'author': 'Bisco Hatori',
#   'original_title': '桜蘭高校ホスト部 4',
#   'original_pub_year': '1999',
#   'avg_rating': 4.45,
#   'ratings_count': 11280},
#  {'author': 'Kristen Ashley',
#   'original_title': 'Ride Steady',
#   'original_pub_year': '2015',
#   'avg_rating': 4.45,
#   'ratings_count': 15388},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': "Harry Potter and the Philosopher's Stone",
#   'original_pub_year': '1997',
#   'avg_rating': 4.44,
#   'ratings_count': 4602479},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Son of Neptune ',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 299980},
#  {'author': 'Robert Kapilow, Dr. Seuss',
#   'original_title': '',
#   'original_pub_year': '',
#   'avg_rating': 4.44,
#   'ratings_count': 90574},
#  {'author': 'Colleen Hoover',
#   'original_title': 'It Ends with Us',
#   'original_pub_year': '2016',
#   'avg_rating': 4.44,
#   'ratings_count': 80433},
#  {'author': 'Mark Cotta Vaz',
#   'original_title': 'Eclipse: The Official Illustrated Movie Companion',
#   'original_pub_year': '2010',
#   'avg_rating': 4.44,
#   'ratings_count': 50084},
#  {'author': 'Tahereh Mafi',
#   'original_title': 'Ignite Me (Shatter Me, #3)',
#   'original_pub_year': '2014',
#   'avg_rating': 4.44,
#   'ratings_count': 83767},
#  {'author': 'Neil Gaiman, Steve Parkhouse, Chris Bachalo, Michael Zulli, Mike Dringenberg, Malcolm Jones III, Todd Klein, Clive Barker',
#   'original_title': "The Doll's House",
#   'original_pub_year': '1990',
#   'avg_rating': 4.44,
#   'ratings_count': 54420},
#  {'author': 'Lawrence Hill',
#   'original_title': 'The Book of Negroes',
#   'original_pub_year': '2007',
#   'avg_rating': 4.44,
#   'ratings_count': 22146},
#  {'author': 'Jennifer L. Armentrout',
#   'original_title': 'Origin',
#   'original_pub_year': '2013',
#   'avg_rating': 4.44,
#   'ratings_count': 63533},
#  {'author': 'Ilona Andrews',
#   'original_title': 'Magic Strikes',
#   'original_pub_year': '2009',
#   'avg_rating': 4.44,
#   'ratings_count': 51165},
#  {'author': 'Jalaluddin Rumi, Coleman Barks',
#   'original_title': 'Essential Rumi',
#   'original_pub_year': '1273',
#   'avg_rating': 4.44,
#   'ratings_count': 26575},
#  {'author': "Flannery O'Connor",
#   'original_title': 'The Complete Stories',
#   'original_pub_year': '1971',
#   'avg_rating': 4.44,
#   'ratings_count': 27352},
#  {'author': 'Brynne Stephens, Lela Dowling, Cynthia Martin, Anne McCaffrey',
#   'original_title': '',
#   'original_pub_year': '1991',
#   'avg_rating': 4.44,
#   'ratings_count': 29556},
#  {'author': 'Brian K. Vaughan, Fiona Staples',
#   'original_title': 'Saga, Volume Five',
#   'original_pub_year': '2015',
#   'avg_rating': 4.44,
#   'ratings_count': 29429},
#  {'author': 'Raymond E. Feist, Michael Avon Oeming, Bryan J.L. Glass, Ryan Stegman',
#   'original_title': 'Magician: Apprentice (The Riftwar Saga, #1) ',
#   'original_pub_year': '1984',
#   'avg_rating': 4.44,
#   'ratings_count': 17782},
#  {'author': 'Ally Carter',
#   'original_title': 'United We Spy',
#   'original_pub_year': '2013',
#   'avg_rating': 4.44,
#   'ratings_count': 22902},
#  {'author': 'Kristen Ashley',
#   'original_title': 'Lady Luck',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 28620},
#  {'author': 'Steven Erikson',
#   'original_title': 'The Crippled God',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 14472},
#  {'author': 'Pablo Neruda, Ilan Stavans',
#   'original_title': 'The Poetry of Pablo Neruda',
#   'original_pub_year': '1974',
#   'avg_rating': 4.44,
#   'ratings_count': 14596},
#  {'author': 'Joe Hill, Gabriel Rodríguez',
#   'original_title': 'Locke & Key, Vol. 4: Keys to the Kingdom',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 17333},
#  {'author': 'Founding Fathers',
#   'original_title': 'The Declaration of Independence and The Constitution of the United States ',
#   'original_pub_year': '1776',
#   'avg_rating': 4.44,
#   'ratings_count': 14047},
#  {'author': 'Karen Kingsbury, Gary Smalley',
#   'original_title': 'Return',
#   'original_pub_year': '2003',
#   'avg_rating': 4.44,
#   'ratings_count': 11737},
#  {'author': 'Kristen Ashley',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.44,
#   'ratings_count': 24641},
#  {'author': 'Masashi Kishimoto',
#   'original_title': '',
#   'original_pub_year': '2000',
#   'avg_rating': 4.44,
#   'ratings_count': 13122},
#  {'author': 'Hervé Tullet, Christopher Franceschelli',
#   'original_title': 'Un livre',
# ...
#   'original_pub_year': '2012',
#   'avg_rating': 4.32,
#   'ratings_count': 8975},
#  {'author': 'J.D. Robb',
#   'original_title': 'Divided in Death (In Death, #18)',
#   'original_pub_year': '2004',
#   'avg_rating': 4.32,
#   'ratings_count': 17321},
#  {'author': 'Sheldon Vanauken, C.S. Lewis',
#   'original_title': 'A Severe Mercy',
#   'original_pub_year': '1977',
#   'avg_rating': 4.32,
#   'ratings_count': 11207},
#  {'author': 'Tyler Hamilton, Daniel Coyle',
#   'original_title': 'The Secret Race: Inside the Hidden World of the Tour de France: Doping, Cover-ups, and Winning at All Costs',
#   'original_pub_year': '2012',
#   'avg_rating': 4.32,
#   'ratings_count': 8711},
#  {'author': 'Lincoln Peirce',
#   'original_title': 'Big Nate on a Roll',
#   'original_pub_year': '2009',
#   'avg_rating': 4.32,
#   'ratings_count': 9873},
#  {'author': 'Shel Silverstein',
#   'original_title': 'The Missing Piece Meets the Big O',
#   'original_pub_year': '1981',
#   'avg_rating': 4.32,
#   'ratings_count': 9056},
#  {'author': 'Lois McMaster Bujold',
#   'original_title': 'Mirror Dance',
#   'original_pub_year': '1994',
#   'avg_rating': 4.32,
#   'ratings_count': 14391},
#  {'author': 'Erin Hunter',
#   'original_title': "Firestar's Quest",
#   'original_pub_year': '2007',
#   'avg_rating': 4.32,
#   'ratings_count': 14773},
#  {'author': 'Christiane Northrup',
#   'original_title': "Women's Bodies, Women's Wisdom: Creating Physical and Emotional Health and Healing",
#   'original_pub_year': '1994',
#   'avg_rating': 4.32,
#   'ratings_count': 9867},
#  {'author': 'Enid Blyton',
#   'original_title': 'The Folk of Faraway Tree',
#   'original_pub_year': '1946',
#   'avg_rating': 4.32,
#   'ratings_count': 11693},
#  {'author': 'Rachel Vincent',
#   'original_title': 'If I Die (Soul Screamers, #5)',
#   'original_pub_year': '2011',
#   'avg_rating': 4.32,
#   'ratings_count': 14153},
#  {'author': 'Joel C. Rosenberg',
#   'original_title': 'The Auschwitz Escape',
#   'original_pub_year': '2014',
#   'avg_rating': 4.32,
#   'ratings_count': 7844},
#  {'author': 'Jan Karon',
#   'original_title': 'In This Mountain (Mitford)',
#   'original_pub_year': '2002',
#   'avg_rating': 4.32,
#   'ratings_count': 11015},
#  {'author': 'Shelly Crane',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.32,
#   'ratings_count': 14408},
#  {'author': 'Timothy J. Keller',
#   'original_title': 'Counterfeit Gods: The Empty Promises of Money, Sex, and Power, and the Only Hope That Matters',
#   'original_pub_year': '2009',
#   'avg_rating': 4.32,
#   'ratings_count': 8783},
#  {'author': 'Yotam Ottolenghi',
#   'original_title': 'Plenty',
#   'original_pub_year': '2010',
#   'avg_rating': 4.32,
#   'ratings_count': 8023},
#  {'author': 'Lynsay Sands',
#   'original_title': 'Vampire, Interrupted',
#   'original_pub_year': '2008',
#   'avg_rating': 4.32,
#   'ratings_count': 15899},
#  {'author': 'Michael Buckley, Peter Ferguson',
#   'original_title': 'The Everafter War (The Sisters Grimm, #7)',
#   'original_pub_year': '2009',
#   'avg_rating': 4.32,
#   'ratings_count': 12493},
#  {'author': 'Anthony Doerr',
#   'original_title': '',
#   'original_pub_year': '2014',
#   'avg_rating': 4.31,
#   'ratings_count': 470001},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Dance with Dragons',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 365954},
#  {'author': 'Ernest Cline',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 349423},
#  {'author': 'Diana Gabaldon',
#   'original_title': 'Dragonfly in Amber',
#   'original_pub_year': '1992',
#   'avg_rating': 4.31,
#   'ratings_count': 178110},
#  {'author': 'C.S. Lewis',
#   'original_title': 'Mere Christianity',
#   'original_pub_year': '1952',
#   'avg_rating': 4.31,
#   'ratings_count': 184759},
#  {'author': 'Stephen King',
#   'original_title': 'On Writing: A Memoir of the Craft',
#   'original_pub_year': '1999',
#   'avg_rating': 4.31,
#   'ratings_count': 131481},
#  {'author': 'Jacob Grimm, Wilhelm Grimm, Josef Scharl, Padraic Colum, Joseph Campbell, Margaret Raine Hunt, James Stern',
#   'original_title': 'Brüder Grimm: Kinder- und Hausmärchen',
#   'original_pub_year': '1812',
#   'avg_rating': 4.31,
#   'ratings_count': 116324},
#  {'author': 'James Herriot',
#   'original_title': 'All Creatures Great And Small',
#   'original_pub_year': '1972',
#   'avg_rating': 4.31,
#   'ratings_count': 64779},
#  {'author': 'Lao Tzu, Gia-Fu Feng, Jane English, Chungliang Al Huang, Rowena Pattee Kryder, Toinette Lippe',
#   'original_title': '道德經 [dào dé jīng]',
#   'original_pub_year': '',
#   'avg_rating': 4.31,
#   'ratings_count': 39863},
#  {'author': 'Nelson Mandela',
#   'original_title': 'Long Walk to Freedom: The Autobiography of Nelson Mandela',
#   'original_pub_year': '1994',
#   'avg_rating': 4.31,
#   'ratings_count': 43927},
#  {'author': 'Stephenie Meyer',
#   'original_title': '',
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 56827},
#  {'author': 'Patricia Briggs',
#   'original_title': 'Blood Bound',
#   'original_pub_year': '2007',
#   'avg_rating': 4.31,
#   'ratings_count': 84677},
#  {'author': 'David Foster Wallace',
#   'original_title': 'Infinite Jest',
#   'original_pub_year': '1996',
#   'avg_rating': 4.31,
#   'ratings_count': 46742},
#  {'author': 'Jeaniene Frost',
#   'original_title': 'One Foot in the Grave',
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 76368},
#  {'author': 'Stormie Omartian',
#   'original_title': 'The Power of a Praying Wife',
#   'original_pub_year': '1996',
#   'avg_rating': 4.31,
#   'ratings_count': 22618},
#  {'author': 'Dr. Seuss',
#   'original_title': 'The Sneetches and Other Stories',
#   'original_pub_year': '1961',
#   'avg_rating': 4.31,
#   'ratings_count': 52954},
#  {'author': 'Jeaniene Frost',
#   'original_title': "At Grave's End",
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 65397},
#  {'author': 'Kevin Henkes',
#   'original_title': 'Chrysanthemum',
#   'original_pub_year': '1991',
#   'avg_rating': 4.31,
#   'ratings_count': 43520},
#  {'author': 'Nicholas D. Kristof, Sheryl WuDunn',
#   'original_title': 'Half the Sky: Turning Oppression into Opportunity for Women Worldwide',
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 37270},
#  {'author': 'Martha Hall Kelly',
#   'original_title': 'Lilac Girls',
#   'original_pub_year': '2016',
#   'avg_rating': 4.31,
#   'ratings_count': 42421},
#  {'author': 'Isabel Wilkerson',
#   'original_title': "The Warmth of Other Suns: The Epic Story of America's Great Migration ",
#   'original_pub_year': '2010',
#   'avg_rating': 4.31,
#   'ratings_count': 31308},
#  {'author': 'Vince Flynn',
#   'original_title': 'Transfer of Power',
#   'original_pub_year': '1999',
#   'avg_rating': 4.31,
#   'ratings_count': 28647},
#  {'author': 'John Flanagan',
#   'original_title': "Erak's Ransom",
#   'original_pub_year': '2007',
#   'avg_rating': 4.31,
#   'ratings_count': 34286},
#  {'author': 'J.I. Packer',
#   'original_title': 'Knowing God',
#   'original_pub_year': '1973',
#   'avg_rating': 4.31,
#   'ratings_count': 29848},
#  {'author': 'K. Bromberg',
#   'original_title': 'Driven',
#   'original_pub_year': '2013',
#   'avg_rating': 4.31,
#   'ratings_count': 41454},
#  {'author': 'Don    Wood, Audrey Wood',
#   'original_title': 'The Little Mouse, the Red Ripe Strawberry, and the Big Hungry Bear',
#   'original_pub_year': '1984',
#   'avg_rating': 4.31,
#   'ratings_count': 30926},
#  {'author': 'H.P. Lovecraft, August Derleth, Robert Bloch',
#   'original_title': 'The Best of H.P. Lovecraft ',
#   'original_pub_year': '1963',
#   'avg_rating': 4.31,
#   'ratings_count': 25841},
#  {'author': 'Rachel Renée Russell',
#   'original_title': 'Tales From a Not-So-Talented Pop Star',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 22337},
#  {'author': 'Jacqueline Carey',
#   'original_title': "Kushiel's Chosen",
#   'original_pub_year': '2002',
#   'avg_rating': 4.31,
#   'ratings_count': 28621},
#  {'author': 'Karen Marie Moning',
#   'original_title': 'Kiss of the Highlander',
#   'original_pub_year': '2001',
#   'avg_rating': 4.31,
#   'ratings_count': 32793},
#  {'author': 'Robert Kirkman, Charlie Adlard',
#   'original_title': 'The Walking Dead, Vol. 3: Safety Behind Bars',
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 23167},
#  {'author': 'N.K. Jemisin',
#   'original_title': 'The Fifth Season',
#   'original_pub_year': '2015',
#   'avg_rating': 4.31,
#   'ratings_count': 20185},
#  {'author': 'Roger Zelazny',
#   'original_title': 'The Great Book of Amber',
#   'original_pub_year': '1999',
#   'avg_rating': 4.31,
#   'ratings_count': 20748},
#  {'author': 'Karen Marie Moning',
#   'original_title': 'The Dark Highlander',
#   'original_pub_year': '2002',
#   'avg_rating': 4.31,
#   'ratings_count': 27639},
#  {'author': 'Neil Gaiman',
#   'original_title': "Don't Panic: The Official Hitchhikers Guide to the Galaxy Companion",
#   'original_pub_year': '1987',
#   'avg_rating': 4.31,
#   'ratings_count': 18015},
#  {'author': 'J.D. Robb',
#   'original_title': 'Holiday in Death',
#   'original_pub_year': '1998',
#   'avg_rating': 4.31,
#   'ratings_count': 24511},
#  {'author': 'Michael J. Sullivan',
#   'original_title': 'The Crown Tower',
#   'original_pub_year': '2013',
#   'avg_rating': 4.31,
#   'ratings_count': 17352},
#  {'author': 'Fábio Moon, Gabriel Bá, Craig Thompson, Dave Stewart, Sean Konot',
#   'original_title': 'Daytripper',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 17679},
#  {'author': 'P.G. Wodehouse',
#   'original_title': 'Right Ho, Jeeves',
#   'original_pub_year': '1934',
#   'avg_rating': 4.31,
#   'ratings_count': 8234},
#  {'author': 'Erin Hunter',
#   'original_title': 'Moonrise',
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 21311},
#  {'author': 'Joseph Boyden',
#   'original_title': 'Three Day Road',
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 14563},
#  {'author': 'Ree Drummond',
#   'original_title': '',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 19153},
#  {'author': 'Shelly Crane',
#   'original_title': 'Defiance',
#   'original_pub_year': '2011',
#   'avg_rating': 4.31,
#   'ratings_count': 22767},
#  {'author': 'Cornelius Ryan',
#   'original_title': 'The Longest Day',
#   'original_pub_year': '1959',
#   'avg_rating': 4.31,
#   'ratings_count': 14949},
#  {'author': 'J.D. Robb',
#   'original_title': 'Memory in Death ',
#   'original_pub_year': '2006',
#   'avg_rating': 4.31,
#   'ratings_count': 19613},
#  {'author': 'Erin Hunter',
#   'original_title': 'Dawn',
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 19824},
#  {'author': 'Anne Bishop',
#   'original_title': 'Murder of Crows',
#   'original_pub_year': '2014',
#   'avg_rating': 4.31,
#   'ratings_count': 22994},
#  {'author': 'Kristen Ashley',
#   'original_title': 'Rock Chick Rescue',
#   'original_pub_year': '2009',
#   'avg_rating': 4.31,
#   'ratings_count': 26661},
#  {'author': 'Lois McMaster Bujold',
#   'original_title': '',
#   'original_pub_year': '1991',
#   'avg_rating': 4.31,
#   'ratings_count': 17549},
#  {'author': 'Caroline Alexander',
#   'original_title': "The Endurance: Shackleton's legendary Antarctic expedition",
#   'original_pub_year': '1998',
#   'avg_rating': 4.31,
#   'ratings_count': 14529},
#  {'author': 'Wendy Mass',
#   'original_title': '',
#   'original_pub_year': '2010',
#   'avg_rating': 4.31,
#   'ratings_count': 15780},
#  {'author': 'Melissa Müller, Rita Kimber, Robert Kimber',
#   'original_title': 'Anne Frank : The Biography',
#   'original_pub_year': '1998',
#   'avg_rating': 4.31,
#   'ratings_count': 15656},
#  {'author': 'Steven Erikson',
#   'original_title': 'Dust of Dreams',
#   'original_pub_year': '2009',
#   'avg_rating': 4.31,
#   'ratings_count': 14435},
#  {'author': 'Martin Luther King Jr., Clayborne Carson',
#   'original_title': 'The Autobiography of Martin Luther King, Jr.',
#   'original_pub_year': '1986',
#   'avg_rating': 4.31,
#   'ratings_count': 11261},
#  {'author': 'Derek Landy',
#   'original_title': 'Playing with Fire',
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 15533},
#  {'author': 'Conn Iggulden',
#   'original_title': 'Lords of the Bow (Conqueror, #2)',
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 11600},
#  {'author': 'J.D. Robb, Nora Roberts',
#   'original_title': 'Betrayal in Death',
#   'original_pub_year': '2001',
#   'avg_rating': 4.31,
#   'ratings_count': 19215},
#  {'author': 'Lynda Mullaly Hunt',
#   'original_title': '',
#   'original_pub_year': '2012',
#   'avg_rating': 4.31,
#   'ratings_count': 16058},
#  {'author': 'Katy Evans',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.31,
#   'ratings_count': 25386},
#  {'author': 'Heather Brewer',
#   'original_title': 'The Chronicles of Vladimir Tod: Eleventh Grade Burns',
#   'original_pub_year': '2010',
#   'avg_rating': 4.31,
#   'ratings_count': 14758},
#  {'author': 'Julia Child',
#   'original_title': 'The Way to Cook',
#   'original_pub_year': '1989',
#   'avg_rating': 4.31,
#   'ratings_count': 11500},
#  {'author': 'Matsuri Hino, Tomo Kimura',
#   'original_title': 'ヴァンパイア騎士 9',
#   'original_pub_year': '2008',
#   'avg_rating': 4.31,
#   'ratings_count': 14193},
#  {'author': "America's Test Kitchen, Carl Tremblay, Daniel J. Van Ackere",
#   'original_title': "The America's Test Kitchen Family Cookbook",
#   'original_pub_year': '2005',
#   'avg_rating': 4.31,
#   'ratings_count': 12081},
#  {'author': 'R.J. Palacio',
#   'original_title': 'The Julian chapter',
#   'original_pub_year': '2014',
#   'avg_rating': 4.31,
#   'ratings_count': 10437},
#  {'author': 'J.D. Robb',
#   'original_title': 'Delusion in Death',
#   'original_pub_year': '2012',
#   'avg_rating': 4.31,
#   'ratings_count': 13716},
#  {'author': 'Rick Riordan',
#   'original_title': '',
#   'original_pub_year': '2014',
#   'avg_rating': 4.31,
#   'ratings_count': 11947},
#  {'author': 'Dave Ramsey',
#   'original_title': 'Financial Peace Revisited',
#   'original_pub_year': '1992',
#   'avg_rating': 4.31,
#   'ratings_count': 10914},
#  {'author': 'Matsuri Hino, Tomo Kimura',
#   'original_title': 'ヴァンパイア騎士 4',
#   'original_pub_year': '2006',
#   'avg_rating': 4.31,
#   'ratings_count': 13515},
#  {'author': 'Andrew Hunt, Dave Thomas',
#   'original_title': 'The Pragmatic Programmer: From Journeyman to Master',
#   'original_pub_year': '1999',
#   'avg_rating': 4.31,
#   'ratings_count': 9416},
#  {'author': 'Madeline Sheehan',
#   'original_title': '',
#   'original_pub_year': '2013',
#   'avg_rating': 4.31,
#   'ratings_count': 18690},
#  {'author': 'Don Richardson',
#   'original_title': 'Peace Child',
#   'original_pub_year': '1974',
#   'avg_rating': 4.31,
#   'ratings_count': 8832},
#  {'author': 'Karen Kingsbury',
#   'original_title': 'Ever After',
#   'original_pub_year': '2006',
#   'avg_rating': 4.31,
#   'ratings_count': 9685},
#  {'author': 'J.D. Robb',
#   'original_title': 'Kindred in Death ',
#   'original_pub_year': '2009',
#   'avg_rating': 4.31,
#   'ratings_count': 13207},
#  {'author': 'Else Holmelund Minarik, Maurice Sendak',
#   'original_title': 'A Kiss for Little Bear',
#   'original_pub_year': '1968',
#   'avg_rating': 4.31,
#   'ratings_count': 11063},
#  {'author': 'Tite Kubo',
#   'original_title': 'BLEACH―ブリーチ―\u30003',
#   'original_pub_year': '2002',
#   'avg_rating': 4.31,
#   'ratings_count': 11365},
#  {'author': 'C.J. Sansom',
#   'original_title': 'Heartstone',
#   'original_pub_year': '2010',
#   'avg_rating': 4.31,
#   'ratings_count': 8297},
#  {'author': 'Sara Donati',
#   'original_title': 'Lake in the Clouds',
#   'original_pub_year': '2002',
#   'avg_rating': 4.31,
#   'ratings_count': 9223},
#  {'author': 'Anne Bishop',
#   'original_title': 'Marked in Flesh',
#   'original_pub_year': '2016',
#   'avg_rating': 4.31,
#   'ratings_count': 11056},
#  {'author': 'Suzanne Collins',
#   'original_title': 'Catching Fire',
#   'original_pub_year': '2009',
#   'avg_rating': 4.3,
#   'ratings_count': 1831039},
#  {'author': 'Orson Scott Card',
#   'original_title': "Ender's Game",
#   'original_pub_year': '1985',
#   'avg_rating': 4.3,
#   'ratings_count': 813439},
#  {'author': 'Elie Wiesel, Marion Wiesel',
#   'original_title': 'Un di Velt Hot Geshvign',
#   'original_pub_year': '1958',
#   'avg_rating': 4.3,
#   'ratings_count': 691231},
#  ...]

# %% [markdown]
# (5 points) Now complete the below function to take two arguments: the list, and an integer value for minimum ratings count. The new function should now sort and filter the list, returning a list of books sorted by average rating that have been rated by more than a specified number of users. Here, you must use an approach using loops and if statements—in subsequent parts, comprehensions and the built-in filter() must be utilized instead (look up documentation and examples).

# %% [markdown]
# Syntax: filter(function, sequence)
#
# function: function that tests if each element of a sequence is true or not.
# sequence: sequence which needs to be filtered, it can be sets, lists, tuples, or containers of any iterators.

# %%
def sort_ratings(listy,num):
    y = sorted(listy, key = lambda x: x['ratings_count'],reverse=True)
    z = []
    for i in y:
        if i['ratings_count'] > num:
            z.append(i)
            
    return z

# %%
j = sort_ratings(l,1000000)[:5]

# %%
j
# Out:
# [{'author': 'Suzanne Collins',
#   'original_title': 'The Hunger Games',
#   'original_pub_year': '2008',
#   'avg_rating': 4.34,
#   'ratings_count': 4780653},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': "Harry Potter and the Philosopher's Stone",
#   'original_pub_year': '1997',
#   'avg_rating': 4.44,
#   'ratings_count': 4602479},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Twilight',
#   'original_pub_year': '2005',
#   'avg_rating': 3.57,
#   'ratings_count': 3866839},
#  {'author': 'Harper Lee',
#   'original_title': 'To Kill a Mockingbird',
#   'original_pub_year': '1960',
#   'avg_rating': 4.25,
#   'ratings_count': 3198671},
#  {'author': 'F. Scott Fitzgerald',
#   'original_title': 'The Great Gatsby',
#   'original_pub_year': '1925',
#   'avg_rating': 3.89,
#   'ratings_count': 2683664}]

# %% [markdown]
# B4: (8 points) Now use the other two approaches to create different versions of the function. See if you can condense your code into a single line for some of the approaches!
#
# First, use a list comprehension inside of the sorted() function:

# %%
def sort_filter(listx,num):
    x = sorted([i for i in listx if i['ratings_count']>num], key = lambda x: x['avg_rating'],reverse=True)
    return x

# %%
sort_filter(l,1000000)[:5]
# Out:
# [{'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Deathly Hallows',
#   'original_pub_year': '2007',
#   'avg_rating': 4.61,
#   'ratings_count': 1746574},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Half-Blood Prince',
#   'original_pub_year': '2005',
#   'avg_rating': 4.54,
#   'ratings_count': 1678823},
#  {'author': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'original_title': 'Harry Potter and the Prisoner of Azkaban',
#   'original_pub_year': '1999',
#   'avg_rating': 4.53,
#   'ratings_count': 1832823},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Goblet of Fire',
#   'original_pub_year': '2000',
#   'avg_rating': 4.53,
#   'ratings_count': 1753043},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Order of the Phoenix',
#   'original_pub_year': '2003',
#   'avg_rating': 4.46,
#   'ratings_count': 1735368}]

# %%
filter_sort = list(filter(lambda x: x['ratings_count'] > 1000000, l))

# %%
filter_sort
# Out:
# [{'author': 'Suzanne Collins',
#   'original_title': 'The Hunger Games',
#   'original_pub_year': '2008',
#   'avg_rating': 4.34,
#   'ratings_count': 4780653},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': "Harry Potter and the Philosopher's Stone",
#   'original_pub_year': '1997',
#   'avg_rating': 4.44,
#   'ratings_count': 4602479},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Twilight',
#   'original_pub_year': '2005',
#   'avg_rating': 3.57,
#   'ratings_count': 3866839},
#  {'author': 'Harper Lee',
#   'original_title': 'To Kill a Mockingbird',
#   'original_pub_year': '1960',
#   'avg_rating': 4.25,
#   'ratings_count': 3198671},
#  {'author': 'F. Scott Fitzgerald',
#   'original_title': 'The Great Gatsby',
#   'original_pub_year': '1925',
#   'avg_rating': 3.89,
#   'ratings_count': 2683664},
#  {'author': 'John Green',
#   'original_title': 'The Fault in Our Stars',
#   'original_pub_year': '2012',
#   'avg_rating': 4.26,
#   'ratings_count': 2346404},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': 'The Hobbit or There and Back Again',
#   'original_pub_year': '1937',
#   'avg_rating': 4.25,
#   'ratings_count': 2071616},
#  {'author': 'J.D. Salinger',
#   'original_title': 'The Catcher in the Rye',
#   'original_pub_year': '1951',
#   'avg_rating': 3.79,
#   'ratings_count': 2044241},
#  {'author': 'Dan Brown',
#   'original_title': 'Angels & Demons ',
#   'original_pub_year': '2000',
#   'avg_rating': 3.85,
#   'ratings_count': 2001311},
#  {'author': 'Jane Austen',
#   'original_title': 'Pride and Prejudice',
#   'original_pub_year': '1813',
#   'avg_rating': 4.24,
#   'ratings_count': 2035490},
#  {'author': 'Khaled Hosseini',
#   'original_title': 'The Kite Runner ',
#   'original_pub_year': '2003',
#   'avg_rating': 4.26,
#   'ratings_count': 1813044},
#  {'author': 'Veronica Roth',
#   'original_title': 'Divergent',
#   'original_pub_year': '2011',
#   'avg_rating': 4.24,
#   'ratings_count': 1903563},
#  {'author': 'George Orwell, Erich Fromm, Celâl Üster',
#   'original_title': 'Nineteen Eighty-Four',
#   'original_pub_year': '1949',
#   'avg_rating': 4.14,
#   'ratings_count': 1956832},
#  {'author': 'George Orwell',
#   'original_title': 'Animal Farm: A Fairy Story',
#   'original_pub_year': '1945',
#   'avg_rating': 3.87,
#   'ratings_count': 1881700},
#  {'author': 'Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-Doubleday',
#   'original_title': 'Het Achterhuis: Dagboekbrieven 14 juni 1942 - 1 augustus 1944',
#   'original_pub_year': '1947',
#   'avg_rating': 4.1,
#   'ratings_count': 1972666},
#  {'author': 'Stieg Larsson, Reg Keeland',
#   'original_title': 'Män som hatar kvinnor',
#   'original_pub_year': '2005',
#   'avg_rating': 4.11,
#   'ratings_count': 1808403},
#  {'author': 'Suzanne Collins',
#   'original_title': 'Catching Fire',
#   'original_pub_year': '2009',
#   'avg_rating': 4.3,
#   'ratings_count': 1831039},
#  {'author': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'original_title': 'Harry Potter and the Prisoner of Azkaban',
#   'original_pub_year': '1999',
#   'avg_rating': 4.53,
#   'ratings_count': 1832823},
#  {'author': 'J.R.R. Tolkien',
#   'original_title': ' The Fellowship of the Ring',
#   'original_pub_year': '1954',
#   'avg_rating': 4.34,
#   'ratings_count': 1766803},
#  {'author': 'Suzanne Collins',
#   'original_title': 'Mockingjay',
#   'original_pub_year': '2010',
#   'avg_rating': 4.03,
#   'ratings_count': 1719760},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Order of the Phoenix',
#   'original_pub_year': '2003',
#   'avg_rating': 4.46,
#   'ratings_count': 1735368},
#  {'author': 'Alice Sebold',
#   'original_title': 'The Lovely Bones',
#   'original_pub_year': '2002',
#   'avg_rating': 3.77,
#   'ratings_count': 1605173},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Chamber of Secrets',
#   'original_pub_year': '1998',
#   'avg_rating': 4.37,
#   'ratings_count': 1779331},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Goblet of Fire',
#   'original_pub_year': '2000',
#   'avg_rating': 4.53,
#   'ratings_count': 1753043},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Deathly Hallows',
#   'original_pub_year': '2007',
#   'avg_rating': 4.61,
#   'ratings_count': 1746574},
#  {'author': 'Dan Brown',
#   'original_title': 'The Da Vinci Code',
#   'original_pub_year': '2003',
#   'avg_rating': 3.79,
#   'ratings_count': 1447148},
#  {'author': 'J.K. Rowling, Mary GrandPré',
#   'original_title': 'Harry Potter and the Half-Blood Prince',
#   'original_pub_year': '2005',
#   'avg_rating': 4.54,
#   'ratings_count': 1678823},
#  {'author': 'William Golding',
#   'original_title': 'Lord of the Flies ',
#   'original_pub_year': '1954',
#   'avg_rating': 3.64,
#   'ratings_count': 1605019},
#  {'author': 'William Shakespeare, Robert           Jackson',
#   'original_title': 'An Excellent conceited Tragedie of Romeo and Juliet',
#   'original_pub_year': '1595',
#   'avg_rating': 3.73,
#   'ratings_count': 1628519},
#  {'author': 'Kathryn Stockett',
#   'original_title': 'The Help',
#   'original_pub_year': '2009',
#   'avg_rating': 4.45,
#   'ratings_count': 1531753},
#  {'author': 'John Steinbeck',
#   'original_title': 'Of Mice and Men ',
#   'original_pub_year': '1937',
#   'avg_rating': 3.84,
#   'ratings_count': 1467496},
#  {'author': 'Arthur Golden',
#   'original_title': 'Memoirs of a Geisha',
#   'original_pub_year': '1997',
#   'avg_rating': 4.08,
#   'ratings_count': 1300209},
#  {'author': 'E.L. James',
#   'original_title': 'Fifty Shades of Grey',
#   'original_pub_year': '2011',
#   'avg_rating': 3.67,
#   'ratings_count': 1338493},
#  {'author': 'Paulo Coelho, Alan R. Clarke',
#   'original_title': 'O Alquimista',
#   'original_pub_year': '1988',
#   'avg_rating': 3.82,
#   'ratings_count': 1299566},
#  {'author': 'Lois Lowry',
#   'original_title': 'The Giver',
#   'original_pub_year': '1993',
#   'avg_rating': 4.12,
#   'ratings_count': 1296825},
#  {'author': 'C.S. Lewis',
#   'original_title': 'The Lion, the Witch and the Wardrobe',
#   'original_pub_year': '1950',
#   'avg_rating': 4.19,
#   'ratings_count': 1531800},
#  {'author': 'George R.R. Martin',
#   'original_title': 'A Game of Thrones',
#   'original_pub_year': '1996',
#   'avg_rating': 4.45,
#   'ratings_count': 1319204},
#  {'author': 'Elizabeth Gilbert',
#   'original_title': "Eat, pray, love: one woman's search for everything across Italy, India and Indonesia",
#   'original_pub_year': '2006',
#   'avg_rating': 3.51,
#   'ratings_count': 1181647},
#  {'author': 'Rick Riordan',
#   'original_title': 'The Lightning Thief',
#   'original_pub_year': '2005',
#   'avg_rating': 4.23,
#   'ratings_count': 1366265},
#  {'author': 'Louisa May Alcott',
#   'original_title': 'Little Women',
#   'original_pub_year': '1868',
#   'avg_rating': 4.04,
#   'ratings_count': 1257121},
#  {'author': 'Charlotte Brontë, Michael Mason',
#   'original_title': 'Jane Eyre',
#   'original_pub_year': '1847',
#   'avg_rating': 4.1,
#   'ratings_count': 1198557},
#  {'author': 'Nicholas Sparks',
#   'original_title': 'The Notebook',
#   'original_pub_year': '1996',
#   'avg_rating': 4.06,
#   'ratings_count': 1053403},
#  {'author': 'Yann Martel',
#   'original_title': 'Life of Pi',
#   'original_pub_year': '2001',
#   'avg_rating': 3.88,
#   'ratings_count': 1003228},
#  {'author': 'Sara Gruen',
#   'original_title': 'Water for Elephants',
#   'original_pub_year': '2006',
#   'avg_rating': 4.07,
#   'ratings_count': 1068146},
#  {'author': 'Markus Zusak',
#   'original_title': 'The Book Thief',
#   'original_pub_year': '2005',
#   'avg_rating': 4.36,
#   'ratings_count': 1159741},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'New Moon (Twilight, #2)',
#   'original_pub_year': '2006',
#   'avg_rating': 3.52,
#   'ratings_count': 1149630},
#  {'author': 'Shel Silverstein',
#   'original_title': 'Where the Sidewalk Ends: The Poems and Drawings of Shel Silverstein',
#   'original_pub_year': '1974',
#   'avg_rating': 4.29,
#   'ratings_count': 1016888},
#  {'author': 'Cassandra Clare',
#   'original_title': 'City of Bones',
#   'original_pub_year': '2007',
#   'avg_rating': 4.12,
#   'ratings_count': 1154031},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Eclipse',
#   'original_pub_year': '2007',
#   'avg_rating': 3.69,
#   'ratings_count': 1134511},
#  {'author': 'Christopher Paolini',
#   'original_title': 'Eragon',
#   'original_pub_year': '2002',
#   'avg_rating': 3.86,
#   'ratings_count': 1104021},
#  {'author': 'Aldous Huxley',
#   'original_title': 'Brave New World',
#   'original_pub_year': '1932',
#   'avg_rating': 3.97,
#   'ratings_count': 1022601},
#  {'author': 'Stephenie Meyer',
#   'original_title': 'Breaking Dawn',
#   'original_pub_year': '2008',
#   'avg_rating': 3.7,
#   'ratings_count': 1070245},
#  {'author': 'E.B. White, Garth Williams, Rosemary Wells',
#   'original_title': "Charlotte's Web",
#   'original_pub_year': '1952',
#   'avg_rating': 4.15,
#   'ratings_count': 1064521},
#  {'author': 'Paula Hawkins',
#   'original_title': 'The Girl on the Train',
#   'original_pub_year': '2015',
#   'avg_rating': 3.88,
#   'ratings_count': 1008778}]

# %%
# Objectively, should the solution in B3 (loops and if statements)be faster or slower than either of the solutions from B4 (list comprehension/filter function)? 
# Print your answer as 'Faster' or 'Slower', below
print("<Slower>")
# Out:
# <Slower>
